# %% [markdown]
# # Lab 1 - Naive Bayes Classifier

# %% [markdown]
# ## Submission rules
#
# 1. Lab 1 is an assignment for teams of 2-3 students; the teams are listed on cms. Please make only one submission per team
# 2. The assignment should be completed in a Google Collaboratory notebook (https://colab.research.google.com/notebooks/intro.ipynb#). To this end, first create a copy of this notebook in your personal Googel Drive via "File" --> "Save a copy in Drive". Do not forget to
#  *    rename the notebook and mention all your teammates in the name;
#  *    share your notebook within ucu.edu.ua domain, so that we will be able to open and grade it :)
# 3. Submit the link to the final version of the notebook in the comments field of cms and list all the team members therein. No changes may be made to the notebook after the deadline
# 4. At the top of your notebook, provide a work-breakdown structure estimating efforts of each team member.
#
# Failure to comply with the submission rules can be a reason of up to 1 point deduction.

# %% [markdown]
# ## Introduction
# During the past three weeks, you learned a couple of essential notions ant theorems. One of them is Bayes theorem.
#
# One of its applications is **Naive Bayes classifier**, which is a probabilistic classifier whose aim is to determine which class some observation probably belongs by using the Bayes formula:
# $$\mathsf{P}(\mathrm{class}\mid \mathrm{observation})=\frac{\mathsf{P}(\mathrm{observation}\mid\mathrm{class})\mathsf{P}(\mathrm{class})}{\mathsf{P}(\mathrm{observation})}$$
#
# Under the strong independence assumption, one can calculate $\mathsf{P}(\mathrm{observation} \mid \mathrm{class})$ as
# $$\mathsf{P}(\mathrm{observation}) = \prod_{i=1}^{n} \mathsf{P}(\mathrm{feature}_i),$$
# where $n$ is the total number of features describing a given observation. Thus, $\mathsf{P}(\mathrm{class}|\mathrm{observation})$ now can be calculated as
#
# $$\mathsf{P}(\mathrm{class} \mid \mathrm{\mathrm{observation}}) = \mathsf{P}(\mathrm{class})\times \prod_{i=1}^{n}\frac{\mathsf{P}(\mathrm{feature}_i\mid \mathrm{class})}{\mathsf{P}(\mathrm{feature}_i)}$$
#
# For more detailed explanation, you can check [this link](https://monkeylearn.com/blog/practical-explanation-naive-bayes-classifier/).

# %% [markdown]
# ## Data  description
#
# There are 5 datasets uploaded on the cms.
#
# To determine your variant, take your team number from the list of teams on cms and take *mod 5* - this is the number of your data set.
#
# * **0 - authors**
# This data set consists of citations of three famous writers: Edgar Alan Poe, Mary Wollstonecraft Shelley and HP Lovecraft. The task with this data set is to classify a piece of text with the author who was more likely to write it.
#
# * **1 - discrimination**
# This data set consists of tweets that have discriminatory (sexism or racism) messages or of tweets that are of neutral mood. The task is to determine whether a given tweet has discriminatory mood or does not.
#
# * **2 - fake news**
# This data set contains data of American news: a headline and an abstract of the article.
# Each piece of news is classified as fake or credible. The task is to classify the news from test.csv as credible or fake.
#
# * **3 - sentiment**
# All the text messages contained in this data set are labeled with three sentiments: positive, neutral or negative. The task is to classify some text message as the one of positive mood, negative or neutral.
#
# * **4 - spam**
# This last data set contains SMS messages classified as spam or non-spam (ham in the data set). The task is to determine whether a given message is spam or non-spam.
#
# Each data set consists of two files: *train.csv* and *test.csv*. The first one you will need find the probabilities distributions for each of the features, while the second one is needed for checking how well your classifier works.

# %% [markdown]
# ##Implementation

# %%
import pandas as pd
from typing import List
from collections import Counter
from string import punctuation
from nltk.stem import PorterStemmer

ps = PorterStemmer()
df = pd.read_csv("train.csv")
df
# Out:
#      sentiment                                               text
# 0      neutral  According to Gran , the company has no plans t...
# 1      neutral  Technopolis plans to develop in stages an area...
# 2     negative  The international electronic industry company ...
# 3     positive  With the new production plant the company woul...
# 4     positive  According to the company 's updated strategy f...
# ...        ...                                                ...
# 3963   neutral  Under the agreement Benefon 's forthcoming ran...
# 3964   neutral  Under the terms of the agreement , Bunge will ...
# 3965   neutral  Under the transaction agreement , Metsaliitto ...
# 3966   neutral  Underground parking facilities will also be bu...
# 3967   neutral  Unit prices for straddle carriers vary between...
#
# [3968 rows x 2 columns]

# %% [markdown]
# ### Data pre-processing
# * Read the *.csv* data files with *pandas* package. This package will also provide you with a nice interface for data processing even within the classifier implementation.
# * Сlear your data from punctuation or other unneeded symbols.
# * Clear you data from stop words. You don’t want words as is, and, or etc. to affect your probabilities distributions, so it is a wise decision to get rid of them. Find list of stop words in the cms under the lab task.
# * Represent each test message as its bag-of-words. [Here](https://machinelearningmastery.com/gentle-introduction-bag-words-model/) you can find general introduction to the bag-of-words model and examples on to create it.

# %%
# your code here
def get_stop_words() -> set:
    """
    Returns set of words to ignore
    """
    words_file_path = "stop_words.txt"
    stop_words = set()
    with open(words_file_path) as f:
        for line in f:
            stop_words.add(line.strip())
    return stop_words

def prepare_sentence(sentence: str) -> str:
    sentence = str(sentence).lower()
    
    for char in punctuation:
        sentence = sentence.replace(char, "")
        
    words = sentence.split()
    stop_words = get_stop_words()
    counter = Counter()
    for word in words:
        if word not in stop_words:
            stem = ps.stem(word)
            counter[stem] += 1
            
    return counter

# %%
def process_data(data_file):
    """
    Function for data processing and split it into X and y sets.
    :param data_file: str - train datado a research of your own
    :return: pd.Series|list, pd.Series|list - X and y data series or lists
    """
    
    df = pd.read_csv(data_file)
    df["text"] = df["text"].apply(prepare_sentence)
    
    
    return list(df["text"].values), list(df["sentiment"].values)
    
result = process_data("train.csv")
result[0]
# Out:
# [Counter({'accord': 1,
#           'gran': 1,
#           'compani': 2,
#           'plan': 1,
#           'move': 1,
#           'product': 1,
#           'russia': 1,
#           'although': 1,
#           'grow': 1}),
#  Counter({'technopoli': 1,
#           'plan': 1,
#           'develop': 1,
#           'stage': 1,
#           'area': 1,
#           'less': 1,
#           '100000': 1,
#           'squar': 1,
#           'meter': 1,
#           'order': 1,
#           'host': 1,
#           'compani': 1,
#           'work': 1,
#           'comput': 1,
#           'technolog': 1,
#           'telecommun': 1,
#           'statement': 1,
#           'said': 1}),
#  Counter({'intern': 1,
#           'electron': 1,
#           'industri': 1,
#           'compani': 2,
#           'elcoteq': 1,
#           'laid': 1,
#           'ten': 1,
#           'employe': 1,
#           'tallinn': 1,
#           'facil': 1,
#           'contrari': 1,
#           'earlier': 1,
#           'layoff': 1,
#           'contract': 1,
#           'rank': 1,
#           'offic': 1,
#           'worker': 1,
#           'daili': 1,
#           'postime': 1,
#           'report': 1}),
#  Counter({'new': 1,
#           'product': 2,
#           'plant': 1,
#           'compani': 1,
#           'increas': 3,
#           'capac': 1,
#           'meet': 1,
#           'expect': 1,
#           'demand': 1,
#           'improv': 1,
#           'use': 1,
#           'raw': 1,
#           'materi': 1,
#           'therefor': 1,
#           'profit': 1}),
#  Counter({'accord': 1,
#           'compani': 1,
#           's': 1,
#           'updat': 1,
#           'strategi': 1,
#           'year': 1,
#           '20092012': 1,
#           'baswar': 1,
#           'target': 1,
#           'longterm': 1,
#           'net': 2,
#           'sale': 2,
#           'growth': 1,
#           'rang': 1,
#           '20': 2,
#           '40': 1,
#           'oper': 1,
#           'profit': 1,
#           'margin': 1,
#           '10': 1}),
#  Counter({'financ': 1,
#           'aspocomp': 2,
#           's': 1,
#           'growth': 2,
#           'aggress': 1,
#           'pursu': 1,
#           'strategi': 1,
#           'increasingli': 1,
#           'focus': 1,
#           'technolog': 1,
#           'demand': 1,
#           'hdi': 1,
#           'print': 1,
#           'circuit': 1,
#           'board': 1,
#           'pcb': 1}),
#  Counter({'last': 1,
#           'quarter': 1,
#           '2010': 1,
#           'componenta': 1,
#           's': 1,
#           'net': 1,
#           'sale': 1,
#           'doubl': 1,
#           'eur131m': 1,
#           'eur76m': 1,
#           'period': 1,
#           'year': 1,
#           'earlier': 1,
#           'move': 1,
#           'zero': 1,
#           'pretax': 2,
#           'profit': 1,
#           'loss': 1,
#           'eur7m': 1}),
#  Counter({'third': 1,
#           'quarter': 1,
#           '2010': 1,
#           'net': 1,
#           'sale': 1,
#           'increas': 1,
#           '52': 1,
#           'eur': 2,
#           '2055': 1,
#           'mn': 2,
#           'oper': 1,
#           'profit': 1,
#           '349': 1,
#           '235': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
#           '131': 1,
#           'mn': 2,
#           '87': 1,
#           'correspond': 1,
#           'period': 1,
#           '2007': 1,
#           'repres': 1,
#           '77': 1,
#           'net': 1,
#           'sale': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'total': 1,
#           'eur': 2,
#           '211': 1,
#           'mn': 2,
#           '186': 1,
#           '2007': 1,
#           'repres': 1,
#           '97': 1,
#           'net': 1,
#           'sale': 1}),
#  Counter({'teliasonera': 1,
#           'tlsn': 1,
#           'said': 1,
#           'offer': 2,
#           'line': 1,
#           'strategi': 1,
#           'increas': 1,
#           'ownership': 1,
#           'core': 1,
#           'busi': 1,
#           'hold': 1,
#           'strengthen': 1,
#           'eesti': 1,
#           'telekom': 1,
#           's': 1,
#           'custom': 1}),
#  Counter({'stora': 1,
#           'enso': 1,
#           'norsk': 1,
#           'skog': 1,
#           'mreal': 1,
#           'upmkymmen': 1,
#           'credit': 1,
#           'suiss': 1,
#           'first': 1,
#           'boston': 1,
#           'cfsb': 1,
#           'rais': 1,
#           'fair': 1,
#           'valu': 1,
#           'share': 1,
#           'four': 1,
#           'largest': 1,
#           'nordic': 1,
#           'forestri': 1,
#           'group': 1}),
#  Counter({'purchas': 1,
#           'agreement': 1,
#           '7200': 1,
#           'ton': 1,
#           'gasolin': 1,
#           'deliveri': 1,
#           'hamina': 1,
#           'termin': 1,
#           'finland': 1,
#           'sign': 1,
#           'nest': 1,
#           'oil': 1,
#           'oyj': 1,
#           'averag': 1,
#           'platt': 1,
#           'index': 1,
#           'septemb': 1,
#           'plu': 1,
#           'eight': 1,
#           'us': 1,
#           'dollar': 1,
#           'per': 1,
#           'month': 1}),
#  Counter({'finnish': 1,
#           'talentum': 1,
#           'report': 1,
#           'oper': 1,
#           'profit': 1,
#           'increas': 1,
#           'eur': 4,
#           '205': 1,
#           'mn': 4,
#           '2005': 1,
#           '93': 1,
#           '2004': 1,
#           'net': 1,
#           'sale': 1,
#           'total': 1,
#           '1033': 1,
#           '964': 1}),
#  Counter({'cloth': 1,
#           'retail': 1,
#           'chain': 1,
#           'sepp�l�': 1,
#           's': 1,
#           'sale': 1,
#           'increas': 1,
#           '8': 1,
#           'eur': 3,
#           '1552': 1,
#           'mn': 3,
#           'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           '311': 1,
#           '171': 1,
#           '2004': 1}),
#  Counter({'consolid': 1,
#           'net': 1,
#           'sale': 1,
#           'increas': 1,
#           '16': 1,
#           'reach': 1,
#           'eur74': 1,
#           '8': 1,
#           'm': 3,
#           'oper': 1,
#           'profit': 1,
#           'amount': 1,
#           'eur0': 2,
#           '9': 1,
#           'compar': 1,
#           'loss': 1,
#           '7': 1,
#           'prior': 1,
#           'year': 1,
#           'period': 1}),
#  Counter({'foundri': 1,
#           'divis': 2,
#           'report': 1,
#           'sale': 2,
#           'increas': 2,
#           '97': 1,
#           'eur': 4,
#           '631': 1,
#           'mn': 4,
#           '575': 1,
#           'correspond': 2,
#           'period': 2,
#           '2006': 2,
#           'machin': 1,
#           'shop': 1,
#           '164': 1,
#           '412': 1,
#           '354': 1}),
#  Counter({'helsinki': 1,
#           'afx': 1,
#           'share': 1,
#           'close': 1,
#           'higher': 1,
#           'led': 1,
#           'nokia': 1,
#           'announc': 1,
#           'plan': 1,
#           'team': 1,
#           'sanyo': 1,
#           'manufactur': 1,
#           '3g': 1,
#           'handset': 1,
#           'nokian': 1,
#           'tyre': 1,
#           'fourthquart': 1,
#           'earn': 1,
#           'report': 1,
#           'beat': 1,
#           'analyst': 1,
#           'expect': 1,
#           'dealer': 1,
#           'said': 1}),
#  Counter({'incap': 2,
#           'contract': 1,
#           'manufactur': 1,
#           'servic': 1,
#           'pvt': 1,
#           'ltd': 1,
#           'subsidiari': 1,
#           'corpor': 1,
#           'finland': 1,
#           'plan': 1,
#           'doubl': 1,
#           'revenu': 1,
#           '20072008': 1}),
#  Counter({'board': 1,
#           'director': 1,
#           'will': 1,
#           'propos': 1,
#           'dividend': 1,
#           'eur0': 2,
#           '12': 1,
#           'per': 2,
#           'share': 2,
#           '2010': 1,
#           '08': 1,
#           'paid': 1,
#           '2009': 1}),
#  Counter({'lifetre': 1,
#           'found': 1,
#           '2000': 1,
#           'revenu': 1,
#           'risen': 1,
#           'averag': 1,
#           '40': 1,
#           'margin': 1,
#           'late': 1,
#           '30': 1}),
#  Counter({'filippova': 1,
#           'trilater': 1,
#           'agreement': 1,
#           'invest': 1,
#           'construct': 1,
#           'technolog': 1,
#           'park': 1,
#           'st': 1,
#           'petersburg': 1,
#           'sign': 1,
#           'cours': 1,
#           'forum': 1,
#           'day': 1,
#           'russian': 1,
#           'economi': 1,
#           'open': 1,
#           'helsinki': 1,
#           'today': 1}),
#  Counter({'megafon': 1,
#           's': 1,
#           'subscrib': 1,
#           'base': 1,
#           'increas': 1,
#           '161': 1,
#           '2009': 2,
#           '505': 1,
#           'million': 1,
#           'user': 1,
#           'decemb': 1,
#           '31': 1,
#           'market': 1,
#           'share': 1,
#           'number': 1,
#           'custom': 1,
#           'amount': 1,
#           '24': 1,
#           'late': 2,
#           '23': 1,
#           '2008': 1,
#           'accord': 1,
#           'teliasonera': 1,
#           'estim': 1}),
#  Counter({'net': 2,
#           'incom': 2,
#           'life': 1,
#           'insur': 2,
#           'doubl': 1,
#           'eur': 4,
#           '68': 1,
#           'mn': 4,
#           '32': 1,
#           'nonlif': 1,
#           'rose': 1,
#           '52': 1,
#           '15': 1,
#           'correspond': 1,
#           'period': 1,
#           '2009': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'increas': 1,
#           'eur193': 1,
#           '3': 1,
#           'm': 3,
#           'eur179': 1,
#           '9': 1,
#           'pretax': 1,
#           'profit': 1,
#           'rose': 1,
#           '342': 1,
#           'eur43': 1,
#           '1': 1,
#           'eur1': 1,
#           'usd1': 1,
#           '4': 1}),
#  Counter({'net': 1,
#           'sale': 2,
#           'surg': 1,
#           '185': 1,
#           'eur167': 1,
#           '8': 1,
#           'm': 2,
#           'telest': 1,
#           'said': 1,
#           'eur20': 1,
#           '4': 1,
#           '122': 1,
#           'came': 1,
#           'acquisit': 1,
#           'made': 1,
#           '2009': 1}),
#  Counter({'nordea': 1,
#           'group': 1,
#           's': 1,
#           'oper': 1,
#           'profit': 1,
#           'increas': 1,
#           '2010': 1,
#           '18': 1,
#           'percent': 2,
#           'yearonyear': 1,
#           '364': 1,
#           'billion': 2,
#           'euro': 2,
#           'total': 1,
#           'revenu': 1,
#           '3': 1,
#           '933': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'ninemonth': 1,
#           'period': 2,
#           'increas': 2,
#           'eur13': 1,
#           '6': 1,
#           'm': 2,
#           'net': 1,
#           'sale': 1,
#           'eur394': 1,
#           '7': 1,
#           'compar': 1,
#           'correspond': 1,
#           '2005': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'ninemonth': 1,
#           'period': 2,
#           'increas': 2,
#           'eur3': 1,
#           '1': 1,
#           'm': 2,
#           'net': 1,
#           'sale': 1,
#           'eur61': 1,
#           '5': 1,
#           'compar': 1,
#           'correspond': 1,
#           '2007': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'threemonth': 1,
#           'period': 2,
#           'increas': 2,
#           'eur1': 1,
#           '2': 2,
#           'm': 2,
#           'revenu': 1,
#           'eur20': 1,
#           'compar': 1,
#           'correspond': 1,
#           '2005': 1}),
#  Counter({'brazilian': 1,
#           'unit': 1,
#           'finnish': 1,
#           'secur': 1,
#           'solut': 1,
#           'provid': 1,
#           'fsecur': 1,
#           'sign': 1,
#           '1500': 1,
#           'new': 1,
#           'client': 1,
#           'last': 1,
#           'year': 1,
#           'onlin': 1,
#           'news': 1,
#           'sourc': 1,
#           'resel': 1,
#           'web': 1,
#           'quot': 1,
#           'divis': 1,
#           's': 1,
#           'commerci': 1,
#           'director': 1,
#           'vladimir': 1,
#           'brando': 1,
#           'say': 1}),
#  Counter({'compani': 2,
#           's': 1,
#           'net': 1,
#           'profit': 1,
#           'rose': 1,
#           '114': 1,
#           'year': 2,
#           '822': 1,
#           'million': 2,
#           'euro': 2,
#           '2005': 1,
#           'sale': 1,
#           '6865': 1,
#           '138': 1,
#           'said': 1,
#           'earlier': 1}),
#  Counter({'lithuanian': 2,
#           'beer': 1,
#           'market': 1,
#           'made': 1,
#           '1441': 1,
#           'million': 1,
#           'liter': 1,
#           'januari': 1,
#           'rise': 1,
#           '08': 1,
#           'percent': 1,
#           'yearearli': 1,
#           'figur': 1,
#           'brewer': 1,
#           'associ': 1,
#           'report': 1,
#           'cite': 1,
#           'result': 1,
#           'member': 1}),
#  Counter({'vike': 1,
#           'line': 1,
#           's': 1,
#           'cargo': 3,
#           'revenu': 1,
#           'increas': 2,
#           '54': 1,
#           'eur': 1,
#           '2146': 1,
#           'mn': 1,
#           'volum': 1,
#           '24': 1,
#           '70116': 1,
#           'unit': 1}),
#  Counter({'fair': 1,
#           'valu': 1,
#           'properti': 1,
#           'portfolio': 1,
#           'doubl': 1,
#           'result': 1,
#           'kapite': 1,
#           'acquisit': 1,
#           'total': 1,
#           'eur': 1,
#           '26862': 1,
#           '12597': 1,
#           'million': 1}),
#  Counter({'10': 1,
#           'februari': 1,
#           '2011': 1,
#           'finnish': 1,
#           'media': 1,
#           'compani': 1,
#           'sanoma': 1,
#           'oyj': 1,
#           'hel': 1,
#           'saa1v': 1,
#           'said': 1,
#           'yesterday': 1,
#           '2010': 1,
#           'net': 1,
#           'profit': 1,
#           'almost': 1,
#           'tripl': 1,
#           'eur297': 1,
#           '3': 1,
#           'm': 2,
#           'eur107': 1,
#           '1': 1,
#           '2009': 1,
#           'announc': 1,
#           'propos': 1,
#           'rais': 1,
#           'payout': 1}),
#  Counter({'helsinki': 1,
#           'eliiv': 1,
#           'today': 1,
#           'report': 1,
#           'ep': 2,
#           'eur1': 2,
#           '13': 1,
#           '2009': 1,
#           'increas': 1,
#           '12': 1,
#           '2008': 1}),
#  Counter({'aspo': 2,
#           'plc': 1,
#           'stock': 1,
#           'exchang': 1,
#           'releas': 1,
#           'februari': 1,
#           '11': 1,
#           '2011': 1,
#           'at8': 1,
#           '45': 1,
#           'esl': 1,
#           'ship': 1,
#           'ltd': 1,
#           'part': 1,
#           'group': 1,
#           'sign': 1,
#           'new': 1,
#           'longterm': 1,
#           'contract': 1,
#           'rautaruukki': 1,
#           'corpor': 1,
#           'marin': 1,
#           'transport': 1,
#           'raw': 1,
#           'materi': 1,
#           'baltic': 1,
#           'sea': 1}),
#  Counter({'commiss': 1,
#           'incom': 1,
#           'increas': 1,
#           '22': 1,
#           'eur': 1,
#           '44': 1,
#           'mn': 1,
#           'lend': 1,
#           'volum': 1,
#           'rose': 1,
#           '135': 1}),
#  Counter({'januari': 1,
#           'traffic': 1,
#           'measur': 2,
#           'revenu': 1,
#           'passeng': 1,
#           'kilometr': 2,
#           'rpk': 1,
#           'went': 1,
#           '32': 1,
#           'capac': 1,
#           'avail': 1,
#           'seat': 1,
#           'ask': 1,
#           'rose': 1,
#           '122': 1}),
#  Counter({'januaryseptemb': 1,
#           '2010': 1,
#           'fiskar': 1,
#           'net': 2,
#           'profit': 1,
#           'went': 1,
#           '14': 1,
#           'yearonyear': 1,
#           'eur': 3,
#           '654': 1,
#           'million': 3,
#           'sale': 1,
#           '5253': 1,
#           '4877': 1}),
#  Counter({'net': 2,
#           'incom': 2,
#           'life': 1,
#           'insur': 2,
#           'rose': 1,
#           'eur': 4,
#           '165': 1,
#           'mn': 4,
#           '140': 1,
#           'nonlif': 1,
#           '226': 1,
#           '152': 1,
#           '2009': 1}),
#  Counter({'nyrstar': 1,
#           'also': 1,
#           'agre': 1,
#           'suppli': 2,
#           'talvivaara': 2,
#           '150000': 1,
#           'tonn': 1,
#           'sulphur': 1,
#           'acid': 1,
#           'per': 1,
#           'annum': 1,
#           'use': 1,
#           's': 1,
#           'leach': 1,
#           'process': 1,
#           'period': 1,
#           'zinc': 1,
#           'concentr': 1}),
#  Counter({'sale': 2,
#           'depart': 1,
#           'store': 2,
#           'divis': 1,
#           'hobbi': 1,
#           'hall': 1,
#           'increas': 1,
#           '7': 1,
#           'cloth': 1,
#           'subsidiari': 1,
#           'seppala': 1,
#           'decreas': 1,
#           '4': 1}),
#  Counter({'sale': 1, 'risen': 1, 'export': 1, 'market': 1}),
#  Counter({'sale': 1,
#           'increas': 2,
#           'due': 1,
#           'grow': 1,
#           'market': 1,
#           'rate': 1,
#           'oper': 1}),
#  Counter({'agreement': 1,
#           'strengthen': 1,
#           'longterm': 1,
#           'partnership': 1,
#           'nokia': 1,
#           'siemen': 1,
#           'network': 1}),
#  Counter({'agreement': 1,
#           'sign': 1,
#           'biohit': 2,
#           'healthcar': 1,
#           'ltd': 1,
#           'ukbas': 1,
#           'subsidiari': 1,
#           'oyj': 1,
#           'finnish': 1,
#           'public': 1,
#           'compani': 1,
#           'develop': 1,
#           'manufactur': 1,
#           'market': 1,
#           'liquid': 1,
#           'handl': 1,
#           'product': 1,
#           'diagnost': 1,
#           'test': 1,
#           'system': 1}),
#  Counter({'compani': 1,
#           'also': 1,
#           'estim': 1,
#           'alreadi': 1,
#           'carri': 1,
#           'invest': 1,
#           'lead': 1,
#           'increas': 1,
#           'net': 1,
#           'sale': 1,
#           '2010': 1,
#           '2009': 1,
#           'reach': 1,
#           'eur': 1,
#           '1417': 1,
#           'million': 1}),
#  Counter({'compani': 1,
#           's': 1,
#           'order': 2,
#           'book': 1,
#           'stood': 1,
#           '15': 1,
#           'bln': 2,
#           'euro': 2,
#           '22': 1,
#           'septemb': 1,
#           '30': 1,
#           '2007': 1,
#           '242': 1,
#           'pct': 1,
#           'year': 1,
#           'intern': 1,
#           'amount': 1,
#           '365': 1,
#           'mln': 2,
#           '5343': 1}),
#  Counter({'compani': 1,
#           'said': 1,
#           'paper': 3,
#           'demand': 1,
#           'increas': 2,
#           'main': 1,
#           'market': 1,
#           'includ': 1,
#           'public': 1,
#           'averag': 1,
#           'price': 1,
#           '4': 1,
#           'percent': 1,
#           'compar': 1,
#           'last': 1,
#           'year': 1}),
#  Counter({'world': 1,
#           's': 1,
#           'second': 1,
#           'largest': 1,
#           'stainless': 1,
#           'steel': 1,
#           'maker': 1,
#           'said': 1,
#           'net': 1,
#           'profit': 1,
#           'threemonth': 1,
#           'period': 1,
#           'dec': 1,
#           '31': 1,
#           'surg': 1,
#           'euro603': 1,
#           'million': 3,
#           'us': 2,
#           '781': 1,
#           'euro3': 1,
#           '33': 1,
#           '431': 1,
#           'per': 2,
#           'share': 2,
#           'euro172': 1,
#           'euro0': 1,
#           '94': 1,
#           'previou': 1,
#           'year': 1}),
#  Counter({'within': 1,
#           'framework': 2,
#           'partnership': 1,
#           'nokia': 1,
#           'siemen': 1,
#           'network': 1,
#           'sign': 1,
#           'initi': 1,
#           'purchas': 1,
#           'agreement': 1,
#           'sitron': 1,
#           'subsidiari': 1,
#           'jsc': 1,
#           'mikron': 1,
#           'largest': 1,
#           'manufactur': 1,
#           'export': 1,
#           'microelectron': 1,
#           'compon': 1,
#           'russia': 1}),
#  Counter({'seppala': 1,
#           's': 1,
#           'revenu': 2,
#           'increas': 2,
#           '02': 1,
#           'eur10': 1,
#           '1': 1,
#           'm': 3,
#           'finland': 1,
#           'went': 1,
#           '24': 1,
#           'eur6': 1,
#           '8': 1,
#           'sale': 2,
#           'abroad': 1,
#           'rose': 1,
#           '62': 1,
#           'eur3': 1,
#           '3': 1,
#           'baltic': 1,
#           'countri': 1,
#           'well': 1,
#           'russia': 1,
#           'ukrain': 1}),
#  Counter({'share': 3,
#           'standard': 1,
#           'charter': 1,
#           'stan': 1,
#           'rose': 2,
#           '12': 1,
#           'ftse': 1,
#           '100': 1,
#           'royal': 1,
#           'bank': 1,
#           'scotland': 1,
#           'rb': 1,
#           '2': 1,
#           'barclay': 1,
#           'barc': 1,
#           'bc': 1,
#           '17': 1}),
#  Counter({'share': 2,
#           'nokia': 1,
#           'corp': 1,
#           'rose': 1,
#           'thursday': 1,
#           'cell': 1,
#           'phone': 1,
#           'maker': 1,
#           'said': 1,
#           'thirdquart': 1,
#           'earn': 1,
#           'almost': 1,
#           'doubl': 1,
#           'global': 1,
#           'handset': 1,
#           'market': 1,
#           'increas': 1}),
#  Counter({'financi': 1,
#           'report': 1,
#           'publish': 1,
#           'friday': 1,
#           'seb': 1,
#           'said': 1,
#           'net': 1,
#           'profit': 1,
#           'soar': 1,
#           'sek6': 1,
#           '745': 1,
#           'bn': 2,
#           '2010': 1,
#           'yearearli': 1,
#           'sek1': 2,
#           '114': 1,
#           'propos': 1,
#           '50': 2,
#           'dividend': 1,
#           'increas': 1,
#           'per': 1,
#           'share': 1}),
#  Counter({'sale': 3,
#           'depart': 1,
#           'store': 2,
#           'divis': 1,
#           'increas': 2,
#           '15': 1,
#           'cloth': 1,
#           'subsidiari': 1,
#           'seppala': 1,
#           '8': 1,
#           'meanwhil': 1,
#           'hobbi': 1,
#           'hall': 1,
#           'decreas': 1,
#           '12': 1}),
#  Counter({'request': 1,
#           'finnish': 1,
#           'media': 2,
#           'compani': 1,
#           'alma': 1,
#           's': 2,
#           'newspap': 1,
#           'research': 2,
#           'manag': 1,
#           'jari': 1,
#           'kaivooja': 1,
#           'finland': 2,
#           'futur': 2,
#           'centr': 1,
#           'turku': 1,
#           'school': 1,
#           'econom': 1,
#           'drawn': 1,
#           'scenario': 1,
#           'nation': 1,
#           'economi': 1,
#           'use': 1,
#           'model': 1,
#           'develop': 1,
#           'univers': 1,
#           'denver': 1}),
#  Counter({'sweden': 1,
#           'gallerix': 1,
#           'accumul': 1,
#           'sek': 1,
#           'denomin': 2,
#           'sale': 2,
#           '1': 1,
#           'eur': 1,
#           '11': 1}),
#  Counter({'compani': 1,
#           'support': 1,
#           'global': 1,
#           'custom': 1,
#           'develop': 2,
#           'new': 1,
#           'technolog': 1,
#           'offer': 1,
#           'fast': 1,
#           'rout': 1,
#           'product': 2,
#           'applic': 1,
#           'volum': 1}),
#  Counter({'invest': 1,
#           'place': 1,
#           'atria': 1,
#           'plan': 1,
#           'expand': 1,
#           'moscow': 1,
#           'market': 1}),
#  Counter({'new': 1,
#           'agreement': 2,
#           'continu': 1,
#           'theagreement': 1,
#           'sign': 2,
#           'earlier': 1,
#           'year': 1,
#           'lemminkainen': 1,
#           'group': 1,
#           'wherebi': 1,
#           'cramo': 1,
#           'acquir': 1,
#           'entir': 1,
#           'construct': 1,
#           'machin': 1,
#           'fleet': 1,
#           'oflemminkainen': 1,
#           'talo': 1,
#           'oy': 1,
#           'ita': 1,
#           'ja': 1,
#           'pohjoi': 1,
#           'suomo': 1,
#           'asimilar': 1,
#           'said': 1,
#           'tatu': 1,
#           'hauhio': 1,
#           'manag': 1,
#           'director': 1,
#           'ofcramo': 1,
#           'finland': 1}),
#  Counter({'first': 1,
#           'contract': 1,
#           'envisag': 1,
#           'construct': 1,
#           'three': 1,
#           'ferryboat': 1,
#           'option': 1,
#           'two': 1,
#           'unit': 1,
#           'confirm': 1,
#           'total': 1,
#           'valu': 1,
#           '500': 1,
#           'mln': 2,
#           'euro': 1,
#           '6458': 1}),
#  Counter({'june': 1,
#           'sold': 1,
#           '30': 1,
#           'percent': 1,
#           'stake': 1,
#           'nordstjernan': 1,
#           'invest': 1,
#           'group': 1,
#           'now': 1,
#           'taken': 1,
#           'option': 1,
#           'acquir': 1,
#           'eqt': 1,
#           's': 1,
#           'remain': 1,
#           'share': 1}),
#  Counter({'kesko': 3,
#           'corpor': 2,
#           'stock': 1,
#           'exchang': 1,
#           'releas': 1,
#           '28022008': 1,
#           '0930': 1,
#           '1': 2,
#           'aspo': 2,
#           'plc': 1,
#           'today': 1,
#           'sign': 1,
#           'agreement': 1,
#           'acquir': 1,
#           'share': 1,
#           'capit': 1,
#           'kaukotelko': 1,
#           'ltd': 1,
#           'subsidiari': 1,
#           'wholli': 1,
#           'own': 1}),
#  Counter({'sponda': 3,
#           'plc': 1,
#           'stock': 1,
#           'exchang': 1,
#           'releas': 1,
#           '5': 1,
#           'decemb': 1,
#           '2006': 1,
#           '1545': 1,
#           'eur': 2,
#           '15': 2,
#           'billion': 2,
#           'syndic': 2,
#           'credit': 2,
#           'facil': 2,
#           'sign': 1,
#           'agreement': 1,
#           'oneyear': 1,
#           'total': 1}),
#  Counter({'stock': 1,
#           'exchang': 1,
#           'announc': 1,
#           '20': 1,
#           'juli': 1,
#           '2006': 1,
#           '1': 2,
#           'baswar': 2,
#           'share': 3,
#           'subscript': 1,
#           'warrant': 2,
#           'increas': 1,
#           'capit': 1,
#           'total': 1,
#           '119': 1,
#           '850': 1,
#           'subscrib': 1,
#           'program': 1}),
#  Counter({'contract': 1,
#           'cover': 1,
#           'hdo': 1,
#           'platform': 1,
#           'ac800': 1,
#           'cxe880': 1,
#           'optic': 1,
#           'fttb': 1,
#           'node': 1,
#           'design': 1,
#           'increas': 1,
#           'forward': 1,
#           'return': 1,
#           'path': 1,
#           'capac': 1,
#           'transmiss': 1,
#           'network': 1}),
#  Counter({'new': 1,
#           'plant': 1,
#           'plan': 1,
#           'electr': 1,
#           'gener': 2,
#           'capac': 2,
#           '350': 1,
#           'megawatt': 1,
#           'mw': 1,
#           'heat': 1}),
#  Counter({'omx': 1,
#           'helsinki': 2,
#           '25': 1,
#           'index': 2,
#           '092': 1,
#           'pct': 2,
#           '251867': 1,
#           'cap': 1,
#           'portfolio': 1,
#           '091': 1,
#           'higher': 1,
#           '471119': 1}),
#  Counter({'sale': 1,
#           'growth': 1,
#           'car': 1,
#           'consider': 1,
#           'influenc': 1,
#           'tire': 1,
#           'market': 1}),
#  Counter({'maximum': 1,
#           '666104': 1,
#           'new': 1,
#           'share': 1,
#           'can': 1,
#           'subscrib': 1,
#           'exercis': 1,
#           'b': 1,
#           'option': 2,
#           '2004': 1,
#           'stock': 1,
#           'plan': 1}),
#  Counter({'result': 1,
#           'share': 4,
#           'issu': 1,
#           'number': 1,
#           'compani': 1,
#           's': 1,
#           'increas': 1,
#           '391630': 1,
#           'capit': 1,
#           'total': 1,
#           'eur': 1,
#           '1566520': 1}),
#  Counter({'finnish': 1,
#           'real': 1,
#           'estat': 1,
#           'investor': 1,
#           'sponda': 1,
#           'plc': 1,
#           'said': 1,
#           'wednesday': 1,
#           '12': 1,
#           'march': 1,
#           'sign': 1,
#           'agreement': 1,
#           'dansk': 1,
#           'bank': 1,
#           'helsinki': 1,
#           'branch': 1,
#           '7year': 2,
#           'eur150m': 1,
#           'credit': 2,
#           'facil': 2,
#           'ilmarinen': 1,
#           'mutual': 1,
#           'pension': 1,
#           'insur': 1,
#           'compani': 1,
#           'eur50m': 1}),
#  Counter({'rout': 1,
#           'helsinki': 1,
#           'finland': 2,
#           'tallinn': 1,
#           'estonia': 1,
#           'cargo': 2,
#           'volum': 2,
#           'increas': 1,
#           '36': 1,
#           'sweden': 1,
#           'fell': 1,
#           '9': 1}),
#  Counter({'measur': 1,
#           'includ': 1,
#           'increas': 1,
#           'synergi': 1,
#           'economi': 1,
#           'scale': 1,
#           'within': 1,
#           'grimaldi': 1,
#           'group': 1,
#           'personnel': 1,
#           'adjust': 1,
#           'divest': 1,
#           'redeliveri': 1,
#           'excess': 1,
#           'tonnag': 1}),
#  Counter({'rinkuskiai': 1,
#           'rais': 1,
#           'sale': 2,
#           '181': 1,
#           'percent': 2,
#           '137': 1,
#           'million': 1,
#           'liter': 2,
#           'kauno': 1,
#           'alu': 1,
#           'grew': 1,
#           '143': 1,
#           '960000': 1}),
#  Counter({'telecomworldwire7': 1,
#           'april': 2,
#           '2006tj': 1,
#           'group': 2,
#           'plc': 2,
#           'sell': 2,
#           'stake': 1,
#           'morn': 2,
#           'digit': 2,
#           'design': 2,
#           'oy': 2,
#           'finnish': 1,
#           'compani': 1,
#           'tj': 1,
#           'said': 1,
#           'friday': 1,
#           '7': 1,
#           'sign': 1,
#           'agreement': 1,
#           'share': 1,
#           'edita': 1,
#           'oyj': 1}),
#  Counter({'telecomworldwire7': 1,
#           'april': 2,
#           '2006tj': 1,
#           'group': 2,
#           'plc': 2,
#           'sell': 2,
#           'stake': 1,
#           'morn': 2,
#           'digit': 2,
#           'design': 2,
#           'oy': 2,
#           'finnish': 1,
#           'compani': 1,
#           'tj': 1,
#           'said': 1,
#           'friday': 1,
#           '7': 1,
#           'sign': 1,
#           'agreement': 1,
#           'share': 1,
#           'edita': 1,
#           'oyj': 1}),
#  Counter({'718430': 1,
#           'new': 1,
#           'seri': 2,
#           'share': 2,
#           'will': 1,
#           'becom': 1,
#           'subject': 1,
#           'trade': 1,
#           'helsinki': 1,
#           'stock': 1,
#           'exchang': 1,
#           's': 1,
#           'main': 1,
#           'list': 1,
#           'togeth': 1,
#           'old': 1,
#           'juli': 1,
#           '3': 1,
#           '2006': 1}),
#  Counter({'fuel': 1,
#           'purchas': 1,
#           'contract': 1,
#           'sign': 1,
#           'three': 1,
#           'month': 1,
#           'deliveri': 1,
#           'septemb': 1,
#           'novemb': 1}),
#  Counter({'tiimari': 1,
#           'oper': 1,
#           '194': 1,
#           'store': 1,
#           'six': 1,
#           'countri': 1,
#           'includ': 1,
#           'core': 1,
#           'finnish': 1,
#           'market': 1,
#           'gener': 1,
#           'turnov': 1,
#           '765': 1,
#           'mln': 1,
#           'eur': 1,
#           '2005': 1}),
#  Counter({'agreement': 1,
#           'biohit': 1,
#           'becom': 1,
#           'focu': 1,
#           'supplier': 1,
#           'pipettor': 2,
#           'dispos': 1,
#           'tip': 1,
#           'vwr': 1,
#           'custom': 1,
#           'throughout': 1,
#           'europ': 1}),
#  Counter({'combin': 1,
#           'servic': 2,
#           'enabl': 1,
#           'us': 1,
#           'offer': 1,
#           'complex': 1,
#           'strengthen': 1,
#           'chain': 1,
#           'limit': 1,
#           'baltic': 1,
#           'port': 1,
#           'connect': 1,
#           'also': 1,
#           'get': 1,
#           'access': 1,
#           'world': 1,
#           'wide': 1,
#           'grimaldi': 1,
#           'network': 1,
#           'mediterranean': 1,
#           'africa': 1,
#           'north': 1,
#           'america': 1,
#           'say': 1,
#           'uwe': 1,
#           'bakosch': 1}),
#  Counter({'blindspot': 1,
#           'come': 1,
#           '1': 1,
#           'vantag': 1,
#           'point': 1,
#           'allow': 1,
#           'investig': 1,
#           'see': 1,
#           'whole': 1,
#           'stori': 1,
#           'high': 1,
#           'resolut': 1,
#           'unbroken': 1,
#           'video': 1}),
#  Counter({'compani': 1,
#           'still': 2,
#           'expect': 1,
#           'turnov': 1,
#           '2010': 1,
#           'slightli': 1,
#           'increas': 1,
#           'level': 1,
#           '2009': 1,
#           'ad': 1,
#           'market': 2,
#           'predict': 1,
#           'poor': 1,
#           'trustworthi': 1,
#           'forecast': 1,
#           'develop': 1,
#           'contract': 1,
#           'manufactur': 1,
#           'busi': 1,
#           'current': 1,
#           'year': 1}),
#  Counter({'acquisit': 1,
#           'will': 1,
#           'consider': 1,
#           'increas': 1,
#           'kemira': 1,
#           's': 1,
#           'sale': 1,
#           'market': 2,
#           'posit': 1,
#           'russian': 1,
#           'metal': 1,
#           'industri': 1,
#           'coat': 1}),
#  Counter({'januaryseptemb': 1,
#           '2007': 1,
#           'finnlin': 1,
#           'net': 1,
#           'sale': 1,
#           'rose': 1,
#           'eur': 2,
#           '5054': 1,
#           'mn': 2,
#           '4735': 1,
#           'correspond': 1,
#           'period': 1,
#           '2006': 1}),
#  Counter({'adjust': 1,
#           'chang': 1,
#           'group': 1,
#           'structur': 1,
#           'divis': 1,
#           's': 1,
#           'net': 1,
#           'sale': 1,
#           'increas': 1,
#           '17': 1}),
#  Counter({'chang': 1,
#           'will': 1,
#           'optim': 1,
#           'oper': 1,
#           'effici': 1,
#           'grow': 1,
#           'busi': 1,
#           'said': 1,
#           'julia': 1,
#           'prohaska': 1,
#           'director': 1,
#           'market': 1,
#           'commun': 1,
#           'fiskar': 1}),
#  Counter({'invest': 1,
#           'physic': 1,
#           'infrastructur': 1,
#           'also': 1,
#           'provid': 1,
#           'knowhow': 1,
#           'manag': 1,
#           'develop': 1,
#           'scienc': 1,
#           'technolog': 1,
#           'park': 1,
#           'said': 1,
#           'sunris': 1,
#           'valley': 1,
#           'director': 1,
#           'andriu': 1,
#           'bagdona': 1}),
#  Counter({'4': 1,
#           'februari': 1,
#           '2011': 1,
#           'finnish': 1,
#           'broadband': 1,
#           'data': 1,
#           'commun': 1,
#           'system': 1,
#           'provid': 1,
#           'telest': 1,
#           'oyj': 1,
#           'hel': 1,
#           'tlt1v': 1,
#           'saw': 1,
#           'net': 1,
#           'profit': 1,
#           'jump': 1,
#           'eur2': 1,
#           '1': 1,
#           'm': 1,
#           'last': 1,
#           'quarter': 1,
#           '2010': 1,
#           'eur995': 1,
#           '000': 1,
#           'period': 1,
#           '2009': 1}),
#  Counter({'finnish': 1,
#           'aktia': 1,
#           'group': 1,
#           's': 1,
#           'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
#           '175': 1,
#           'mn': 2,
#           'first': 2,
#           'quarter': 2,
#           '2010': 1,
#           '82': 1,
#           '2009': 1}),
#  Counter({'finnish': 1,
#           'bank': 1,
#           'land': 1,
#           's': 1,
#           'consolid': 1,
#           'net': 1,
#           'oper': 1,
#           'profit': 1,
#           'increas': 1,
#           'eur': 2,
#           '48': 1,
#           'mn': 2,
#           'first': 2,
#           'quarter': 2,
#           '2005': 1,
#           '64': 1,
#           '2006': 1}),
#  Counter({'finnish': 1,
#           'financi': 1,
#           'group': 1,
#           'aktia': 1,
#           'report': 1,
#           'oper': 1,
#           'profit': 1,
#           'eur': 2,
#           '444': 1,
#           'mn': 2,
#           'januaryseptemb': 1,
#           '2009': 1,
#           '373': 1,
#           'correspond': 1,
#           'period': 1,
#           '2008': 1}),
#  Counter({'finnish': 1,
#           'high': 1,
#           'technolog': 1,
#           'provid': 1,
#           'vaahto': 1,
#           'group': 1,
#           'report': 1,
#           'net': 1,
#           'sale': 1,
#           'eur': 1,
#           '418': 1,
#           'mn': 1,
#           'account': 1,
#           'period': 1,
#           'septemb': 1,
#           '2007': 1,
#           'februari': 1,
#           '2008': 1,
#           'increas': 1,
#           '112': 1,
#           'year': 1,
#           'earlier': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'finnish': 1,
#           'food': 1,
#           'industri': 1,
#           'compani': 1,
#           'l�nnen': 1,
#           'tehtaat': 1,
#           's': 1,
#           'continu': 1,
#           'oper': 1,
#           'increas': 1,
#           '13': 1,
#           '2008': 1,
#           'eur': 2,
#           '3491': 1,
#           'mn': 2,
#           '3096': 1,
#           '2007': 1}),
#  Counter({'individu': 1,
#           'promot': 1,
#           'also': 1,
#           'gener': 1,
#           'slightli': 1,
#           'higherthanexpect': 1,
#           'revenu': 1}),
#  Counter({'biohit': 1,
#           'alreadi': 1,
#           'servic': 1,
#           'mani': 1,
#           'current': 1,
#           'genesi': 1,
#           'custom': 2,
#           'base': 1,
#           'expect': 1,
#           'expand': 1,
#           'result': 1,
#           'agreement': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'turnov': 1,
#           'threemonth': 1,
#           'period': 2,
#           'increas': 1,
#           'respect': 1,
#           'eur0': 1,
#           '9': 1,
#           'm': 2,
#           'eur8': 1,
#           '3': 1,
#           'compar': 1,
#           'correspond': 1,
#           '2005': 1}),
#  Counter({'circul': 1,
#           'revenu': 1,
#           'increas': 1,
#           '5': 1,
#           'finland': 1,
#           '4': 1,
#           'sweden': 1,
#           '2008': 1}),
#  Counter({'cloth': 1,
#           'chain': 1,
#           'sepp�l�': 1,
#           's': 1,
#           'net': 1,
#           'sale': 1,
#           'increas': 1,
#           '70': 1,
#           'eur': 1,
#           '308': 1,
#           'mn': 1}),
#  Counter({'construct': 1,
#           'volum': 1,
#           'meanwhil': 1,
#           'grow': 1,
#           'rate': 1,
#           '1015': 1,
#           'percent': 1,
#           'annual': 1}),
#  Counter({'finnish': 1,
#           'swedish': 1,
#           'construct': 1,
#           'market': 1,
#           'still': 1,
#           'experienc': 1,
#           'estim': 1,
#           '4': 1,
#           'annual': 1,
#           'growth': 1,
#           '2008': 1}),
#  Counter({'howev': 1,
#           'biohit': 1,
#           'estim': 1,
#           'total': 1,
#           'net': 2,
#           'sale': 2,
#           'will': 2,
#           'continu': 1,
#           'grow': 1,
#           '2009': 2,
#           'favour': 1,
#           'trend': 1,
#           'lead': 1,
#           'profit': 1}),
#  Counter({'2009': 1,
#           'fiskar': 1,
#           'cash': 1,
#           'flow': 1,
#           'oper': 1,
#           'activ': 1,
#           'amount': 1,
#           'eur121m': 1,
#           'eur97m': 1,
#           'previou': 1,
#           'year': 1}),
#  Counter({'lithuania': 1,
#           'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
#           '190000': 1,
#           '70000': 1,
#           'correspond': 1,
#           'period': 1,
#           '2005': 1}),
#  Counter({'fourth': 2,
#           'quarter': 2,
#           '2008': 1,
#           'net': 1,
#           'sale': 1,
#           'increas': 1,
#           '2': 1,
#           'eur': 2,
#           '10507': 1,
#           'mn': 2,
#           '10270': 1,
#           '2007': 1}),
#  Counter({'intern': 1,
#           'sale': 1,
#           'rose': 1,
#           '598': 1,
#           'eur': 1,
#           '12444': 1,
#           'mn': 1}),
#  Counter({'kalmar': 1,
#           'espana': 1,
#           'gener': 1,
#           'net': 1,
#           'sale': 1,
#           '113': 1,
#           'mln': 2,
#           'euro': 1,
#           '148': 1,
#           '2005': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'grew': 1,
#           'period': 1,
#           'x20ac': 2,
#           '402': 1,
#           'million': 3,
#           '585u': 1,
#           '401': 1,
#           '2006': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'increas': 1,
#           'eur655m': 1,
#           'april': 1,
#           'june': 1,
#           '2010': 1,
#           'eur438m': 1,
#           'year': 1,
#           'earlier': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'rose': 1,
#           '255': 1,
#           'yearonyear': 1,
#           'eur59': 1,
#           '6': 1,
#           'm': 1,
#           'number': 1,
#           'charger': 1,
#           'deliv': 1,
#           'went': 1,
#           '41': 1,
#           '659': 1,
#           'million': 1,
#           'piec': 1}),
#  Counter({'net': 1,
#           'sale': 1,
#           'total': 1,
#           'eur': 2,
#           '936': 1,
#           'mn': 2,
#           '932': 1,
#           'correspond': 1,
#           'period': 1,
#           '2005': 1}),
#  Counter({'nokia': 1,
#           'also': 1,
#           'note': 1,
#           'averag': 1,
#           'sell': 1,
#           'price': 1,
#           'handset': 1,
#           'declin': 1,
#           'period': 1,
#           'though': 1,
#           'mobil': 1,
#           'phone': 1,
#           'profit': 1,
#           'margin': 1,
#           'rose': 1,
#           '22': 1,
#           'percent': 2,
#           '13': 1,
#           'yearago': 1,
#           'quarter': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'increas': 1,
#           '1451': 1,
#           'eur': 2,
#           '83': 1,
#           'mn': 2,
#           '34': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'margin': 1,
#           'increas': 1,
#           '112': 1,
#           '117': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
#           '311': 1,
#           'mn': 2,
#           '122': 1,
#           'correspond': 1,
#           'period': 1,
#           '2009': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
#           '5mn': 1,
#           '28': 1,
#           'mn': 1,
#           'fourth': 1,
#           'quarter': 1,
#           '2008': 1}),
#  Counter({'oper': 1, 'profit': 1, 'eur': 2, '245': 1, 'mn': 2, '230': 1}),
#  Counter({'ramir': 1,
#           's': 1,
#           'net': 1,
#           'sale': 1,
#           'second': 1,
#           'quarterend': 1,
#           'june': 1,
#           '30': 1,
#           'euro': 2,
#           '1287': 1,
#           'million': 3,
#           'us': 1,
#           '163': 1,
#           '33percent': 1,
#           'increas': 1,
#           'compar': 1,
#           '1246': 1,
#           'thesecond': 1,
#           'quarter': 1,
#           'last': 1,
#           'year': 1}),
#  Counter({'revenu': 1,
#           'grew': 1,
#           '2': 1,
#           'percent': 1,
#           'x20ac': 2,
#           '580': 1,
#           'million': 3,
#           '743': 1,
#           '569': 1}),
#  Counter({'ruukki': 1,
#           'announc': 1,
#           'sign': 1,
#           'agreement': 1,
#           'aker': 1,
#           'solut': 1,
#           'norway': 1,
#           'suppli': 1,
#           '24': 1,
#           'suction': 1,
#           'anchor': 1,
#           'septemb': 1,
#           '2010': 1,
#           'kalajoki': 1,
#           'unit': 1,
#           'finland': 1}),
#  Counter({'ruukki': 1,
#           's': 2,
#           'deliveri': 1,
#           'volum': 1,
#           'sell': 1,
#           'price': 1,
#           'show': 1,
#           'favour': 1,
#           'develop': 1,
#           'compani': 1,
#           'compar': 1,
#           'net': 1,
#           'sale': 1,
#           'grew': 1,
#           '50': 1,
#           'yearonyear': 1,
#           'eur647m': 1,
#           'ceo': 1,
#           'sakari': 1,
#           'tamminen': 1,
#           'said': 1}),
#  Counter({'sanoma': 1,
#           'magazin': 1,
#           'net': 1,
#           'sale': 1,
#           'estim': 1,
#           'grow': 1,
#           '2006': 1}),
#  Counter({'bank': 1,
#           'forecast': 1,
#           'finland': 1,
#           's': 1,
#           'gdp': 1,
#           'will': 1,
#           'grow': 1,
#           '2': 1,
#           '2010': 1,
#           '2011': 1}),
#  Counter({'circuit': 1,
#           's': 1,
#           'overal': 1,
#           'product': 1,
#           'rate': 1,
#           'weekli': 1,
#           'basi': 1,
#           'now': 1,
#           'excess': 2,
#           'averag': 1,
#           '40000': 1,
#           'tonn': 2,
#           'per': 2,
#           'day': 3,
#           'volum': 1,
#           '50000': 1,
#           'reach': 1,
#           'individu': 1}),
#  Counter({'compani': 1,
#           's': 1,
#           'consolid': 1,
#           'oper': 1,
#           'profit': 1,
#           'amount': 1,
#           'eur': 2,
#           '1586': 1,
#           'mn': 2,
#           '414': 1,
#           'yearonyear': 1}),
#  Counter({'depart': 1,
#           'store': 1,
#           'divis': 1,
#           'report': 1,
#           'increas': 1,
#           'sale': 1,
#           '4': 1,
#           'per': 1,
#           'cent': 1}),
#  Counter({'fair': 1,
#           'valu': 1,
#           'compani': 1,
#           's': 1,
#           'invest': 1,
#           'properti': 1,
#           'grew': 1,
#           'eur': 2,
#           '2803': 1,
#           'billion': 1,
#           'end': 1,
#           'march': 1,
#           '2009': 1,
#           '2691': 1,
#           'million': 1,
#           'year': 1,
#           'ago': 1}),
#  Counter({'last': 1,
#           'quarter': 2,
#           'best': 1,
#           '2009': 1,
#           'net': 1,
#           'sale': 1,
#           'oper': 1,
#           'margin': 1,
#           'rose': 1,
#           '122': 1}),
#  Counter({'major': 1,
#           'breweri': 1,
#           'increas': 1,
#           'domest': 1,
#           'beer': 1,
#           'sale': 1,
#           '45': 1,
#           'per': 1,
#           'cent': 1,
#           'last': 1,
#           'year': 1,
#           '25688': 1,
#           'million': 2,
#           'litr': 2,
#           '24592': 1,
#           '2004': 1}),
#  Counter({'transact': 1,
#           'doubl': 1,
#           'tecnomen': 1,
#           'workfors': 1,
#           'add': 1,
#           'fourth': 1,
#           'net': 1,
#           'sale': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           '269': 1,
#           'eur': 1,
#           '1058': 1,
#           '834': 1,
#           'million': 1}),
#  Counter({'purchas': 1,
#           'cramo': 1,
#           'will': 1,
#           'becom': 1,
#           'second': 1,
#           'largest': 1,
#           'rental': 1,
#           'servic': 1,
#           'provid': 1,
#           'latvian': 1,
#           'market': 1}),
#  Counter({'prioriti': 1,
#           '2009': 1,
#           'strengthen': 1,
#           'compani': 1,
#           's': 1,
#           'balanc': 1,
#           'sheet': 1,
#           'increas': 1,
#           'cash': 1,
#           'flow': 1,
#           'ceo': 1,
#           'hannu': 1,
#           'krook': 1,
#           'said': 1}),
#  Counter({'purchas': 1,
#           'oper': 1,
#           'part': 1,
#           'yit': 1,
#           's': 1,
#           'strategi': 1,
#           'expand': 1,
#           'offer': 1,
#           'build': 1,
#           'system': 1,
#           'servic': 1,
#           'geograph': 1}),
#  Counter({'21': 1,
#           'octob': 1,
#           '2010': 2,
#           'finnish': 1,
#           'fish': 1,
#           'tackl': 1,
#           'compani': 1,
#           'rapala': 1,
#           'vmc': 1,
#           'corp': 1,
#           'hel': 1,
#           'rap1v': 1,
#           'said': 1,
#           'today': 1,
#           'net': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur18': 1,
#           '9': 1,
#           'm': 2,
#           'first': 1,
#           'nine': 1,
#           'month': 1,
#           'eur15': 1,
#           '1': 1,
#           'period': 1,
#           'year': 1,
#           'earlier': 1}),
#  Counter({'structur': 1,
#           'bim': 1,
#           'build': 1,
#           'inform': 1,
#           'model': 1,
#           'softwar': 2,
#           'tekla': 1,
#           'modelbas': 1,
#           'provid': 1,
#           'adopt': 1,
#           'construct': 1,
#           'manag': 1,
#           'deliveri': 1,
#           'univers': 1,
#           'project': 1,
#           'abu': 1,
#           'dhabi': 1}),
#  Counter({'accord': 1,
#           'finnish': 1,
#           'metso': 1,
#           'miner': 1,
#           'valu': 1,
#           'compani': 1,
#           's': 1,
#           'order': 1,
#           'gone': 1,
#           'eur': 1,
#           '19': 1,
#           'bn': 1,
#           '12': 1,
#           'month': 1}),
#  Counter({'finnish': 1,
#           'aldata': 1,
#           'solut': 1,
#           'sign': 1,
#           'contract': 1,
#           'suppli': 1,
#           'gold': 1,
#           'system': 1,
#           'two': 1,
#           'french': 1,
#           'retail': 1,
#           'chain': 1}),
#  Counter({'finnish': 1,
#           'bank': 1,
#           'land': 1,
#           'report': 1,
#           'oper': 1,
#           'profit': 1,
#           'rose': 1,
#           'eur': 2,
# ...
#           'ozk': 1,
#           'kardzhali': 1,
#           'smelter': 1,
#           'bulgaria': 1}),
#  Counter({'finnish': 1,
#           'p�yri': 1,
#           'award': 1,
#           'engin': 1,
#           'contract': 1,
#           'cfr': 1,
#           'nation': 1,
#           'railway': 1,
#           'compani': 1,
#           'romania': 1}),
#  Counter({'accord': 1,
#           'report': 1,
#           'neomarkka': 1,
#           'kuitu': 1,
#           'finland': 1,
#           's': 2,
#           'custom': 1,
#           'interest': 1,
#           'buy': 1,
#           'compani': 1,
#           'product': 2,
#           'restart': 1}),
#  Counter({'result': 1,
#           'distribut': 2,
#           'compani': 1,
#           'will': 1,
#           'start': 1,
#           'addit': 1,
#           'current': 1,
#           'product': 2,
#           'offer': 1,
#           'shimano': 2,
#           'reel': 1,
#           'rod': 1,
#           'fish': 1,
#           'tackl': 1,
#           'exclus': 1,
#           'basi': 1}),
#  Counter({'cargotec': 1,
#           'germani': 1,
#           'gmbh': 1,
#           'award': 1,
#           'contract': 1,
#           'stadtverwaltung': 1,
#           'mainz': 1,
#           'chassi': 1,
#           'bodi': 1,
#           'open': 1,
#           'procedur': 1}),
#  Counter({'ceo': 1,
#           'erkki': 1,
#           'j�rvinen': 1,
#           'happi': 1,
#           'compani': 1,
#           's': 1,
#           'perform': 1,
#           '2010': 1}),
#  Counter({'deliveri': 1,
#           'start': 1,
#           'network': 1,
#           'will': 1,
#           'readi': 1,
#           'launch': 1,
#           'soon': 1}),
#  Counter({'earn': 1,
#           'per': 1,
#           'share': 1,
#           'quarter': 1,
#           'also': 1,
#           'higher': 1,
#           'yearonyear': 1,
#           '033': 1,
#           'eur': 2,
#           'versu': 1,
#           '027': 1,
#           'market': 1,
#           'expect': 1,
#           '028': 1}),
#  Counter({'ebitda': 1,
#           'year': 1,
#           '2009': 1,
#           'improv': 1,
#           'eur484m': 1,
#           'compar': 1,
#           'eur472m': 1,
#           '2008': 1}),
#  Counter({'estonian': 2,
#           'telecom': 1,
#           'compani': 3,
#           'elisa': 2,
#           's': 1,
#           'custom': 1,
#           'number': 2,
#           'cross': 1,
#           '400000': 1,
#           'tallinn': 1,
#           'oct': 1,
#           '22': 1,
#           'bn': 1,
#           'telecommun': 1,
#           'won': 1,
#           'approxim': 1,
#           '50000': 1,
#           'new': 1,
#           'client': 1,
#           'nine': 1,
#           'month': 1,
#           'year': 1,
#           'bring': 1,
#           '401800': 1,
#           'end': 1,
#           'septemb': 1,
#           'said': 1}),
#  Counter({'exel': 1,
#           'composit': 1,
#           'longterm': 1,
#           'growth': 1,
#           'prospect': 1,
#           'remain': 1,
#           'favour': 1,
#           'howev': 1}),
#  Counter({'fi': 1,
#           'develop': 1,
#           'cooper': 1,
#           'keyword': 1,
#           'advertis': 1,
#           'microsoft': 1}),
#  Counter({'finnish': 1,
#           'construct': 1,
#           'group': 1,
#           'lemminkainen': 1,
#           'oyj': 1,
#           'hel': 1,
#           'lem1': 1,
#           'said': 1,
#           'today': 1,
#           'won': 1,
#           'contract': 1,
#           'provid': 1,
#           'technic': 1,
#           'servic': 1,
#           'nevski': 1,
#           'centr': 1,
#           'shop': 1,
#           'mall': 1,
#           'open': 1,
#           'novemb': 1,
#           'st': 1,
#           'petersburg': 1,
#           'russia': 1}),
#  Counter({'finnish': 1,
#           'mobil': 1,
#           'oper': 1,
#           'dna': 1,
#           'will': 2,
#           'function': 1,
#           'subcontractor': 1,
#           'maingat': 1,
#           'respons': 1,
#           'telecommun': 1,
#           'connect': 1}),
#  Counter({'finnish': 1,
#           'softwar': 2,
#           'develop': 1,
#           'baswar': 2,
#           'oyj': 1,
#           'said': 1,
#           'novemb': 1,
#           '30': 1,
#           '2006': 1,
#           'us': 2,
#           'subsidiari': 1,
#           'inc': 1,
#           'won': 1,
#           'order': 1,
#           'provid': 1,
#           'contract': 1,
#           'lifecycl': 1,
#           'manag': 1,
#           'unnam': 1,
#           'medic': 1,
#           'technolog': 1,
#           'compani': 1}),
#  Counter({'honka': 1,
#           's': 1,
#           'subsidiari': 1,
#           'franc': 1,
#           'germani': 1,
#           'will': 1,
#           'also': 1,
#           'benefit': 1,
#           'exampl': 1,
#           'arrang': 1,
#           'custom': 1,
#           'event': 1,
#           'conjunct': 1,
#           'world': 1,
#           'cup': 1,
#           'ski': 1,
#           'competit': 1}),
#  Counter({'howev': 1,
#           'sale': 1,
#           'volum': 1,
#           'food': 1,
#           'industri': 1,
#           'expect': 1,
#           'remain': 1,
#           'rel': 1,
#           'good': 1,
#           'level': 1,
#           'finland': 1,
#           'scandinavia': 1,
#           'atria': 1,
#           'said': 1}),
#  Counter({'incap': 1,
#           'lankapaja': 1,
#           'aim': 1,
#           'enter': 1,
#           'actual': 1,
#           'agreement': 1,
#           'transfer': 2,
#           'sheetmet': 1,
#           'product': 1,
#           'buyer': 1,
#           'februari': 1,
#           'order': 1,
#           'complet': 1,
#           '1': 1,
#           'march': 1,
#           '2011': 1}),
#  Counter({'mr': 1,
#           'kivimeist': 1,
#           'said': 1,
#           'john': 1,
#           'deer': 1,
#           'former': 1,
#           'timberjack': 1,
#           'stand': 1,
#           'win': 1,
#           'situat': 1,
#           'control': 1,
#           'around': 1,
#           '60': 1,
#           'estonia': 1,
#           's': 1,
#           'forest': 1,
#           'machineri': 1,
#           'market': 1}),
#  Counter({'nokia': 1,
#           'elisa': 2,
#           'will': 1,
#           'work': 1,
#           'togeth': 1,
#           'bring': 1,
#           'superior': 1,
#           'mobil': 1,
#           'game': 1,
#           'experi': 1,
#           'custom': 1}),
#  Counter({'nordea': 1,
#           'see': 1,
#           'return': 1,
#           'posit': 1,
#           'growth': 1,
#           'baltic': 1,
#           'countri': 1,
#           '2011': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'improv': 1,
#           '167': 1,
#           'eur': 1,
#           '77': 1,
#           'mn': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'improv': 1,
#           '399': 1,
#           'eur': 1,
#           '180': 1,
#           'mn': 2,
#           'eur12': 1,
#           '8': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'improv': 1,
#           '440': 1,
#           'er': 1,
#           '47': 1,
#           'mn': 2,
#           'eur': 1,
#           '33': 1,
#           '2004': 1}),
#  Counter({'oper': 1,
#           'profit': 1,
#           'improv': 1,
#           'eur': 2,
#           '203': 1,
#           'mn': 2,
#           '114': 1}),
#  Counter({'outokumpu': 1,
#           's': 1,
#           'chief': 1,
#           'execut': 1,
#           'juha': 1,
#           'rantanen': 1,
#           'express': 1,
#           'confid': 1,
#           'china': 1,
#           'market': 1}),
#  Counter({'previous': 1,
#           'compani': 1,
#           'anticip': 1,
#           'oper': 1,
#           'profit': 1,
#           'improv': 1,
#           'period': 1}),
#  Counter({'product': 1, 'situat': 1, 'now': 1, 'improv': 1}),
#  Counter({'rautaruukki': 1,
#           'said': 1,
#           'construct': 1,
#           'group': 1,
#           'yit': 1,
#           'award': 1,
#           '25': 1,
#           'mln': 1,
#           'eur': 1,
#           'contract': 1,
#           'suppli': 1,
#           'steel': 1,
#           'structur': 1,
#           'new': 1,
#           'bridg': 1,
#           'span': 1,
#           'kemijoki': 1,
#           'river': 1,
#           'northern': 1,
#           'finland': 1}),
#  Counter({'sale': 1,
#           'came': 1,
#           '241': 1,
#           'mln': 3,
#           'eur': 2,
#           'compar': 1,
#           '2114': 1,
#           'also': 1,
#           'beat': 1,
#           'consensu': 1,
#           'forecast': 1,
#           '235': 1}),
#  Counter({'sale': 1,
#           'vat': 1,
#           'inclus': 1,
#           'expand': 1,
#           '19': 1,
#           'percent': 1,
#           '351': 1,
#           'million': 1,
#           'euro': 1}),
#  Counter({'strong': 1, 'growth': 1, 'continu': 1, 'also': 1, 'china': 1}),
#  Counter({'synergi': 1,
#           'benefit': 1,
#           'will': 1,
#           'start': 1,
#           'materialis': 1,
#           'second': 1,
#           'quarter': 1}),
#  Counter({'telest': 2,
#           'sentri': 2,
#           '360': 1,
#           'form': 1,
#           'integr': 1,
#           'partnership': 1,
#           's': 2,
#           'advanc': 1,
#           '360degre': 1,
#           'immers': 1,
#           'camera': 1,
#           'product': 1,
#           'line': 1,
#           'enterpris': 1,
#           'video': 1,
#           'manag': 1,
#           'system': 1}),
#  Counter({'thank': 1,
#           'multipli': 1,
#           'effect': 1,
#           'wagon': 1,
#           'perform': 1,
#           'transport': 1,
#           'will': 1,
#           'much': 1,
#           'effici': 1,
#           'say': 1,
#           'develop': 1,
#           'manag': 1,
#           'juha': 1,
#           'malkia': 1,
#           'vr': 1,
#           'cargo': 1}),
#  Counter({'buy': 1, 'recommend': 1, 'reiter': 1}),
#  Counter({'aim': 1,
#           'achiev': 1,
#           'eur': 1,
#           '25': 1,
#           'mn': 1,
#           'yearli': 1,
#           'save': 1}),
#  Counter({'borrow': 1,
#           'happi': 1,
#           'roadshow': 1,
#           'paid': 1,
#           'hit': 1,
#           'ratio': 1,
#           'high': 1}),
#  Counter({'compani': 1,
#           'make': 1,
#           'garden': 1,
#           'tool': 1,
#           'scissor': 1,
#           'consum': 1,
#           'good': 1,
#           'said': 1,
#           'earn': 1,
#           'boost': 1,
#           '69': 1,
#           'mln': 1,
#           'eur': 1,
#           'incom': 1,
#           'receiv': 1,
#           '167': 1,
#           'pct': 1,
#           'sharehold': 1,
#           'finnish': 1,
#           'engin': 1,
#           'group': 1,
#           'wartsila': 1}),
#  Counter({'compani': 1,
#           'anticip': 1,
#           'turnov': 1,
#           'whole': 1,
#           '2010': 1,
#           'surpass': 1,
#           'previou': 1,
#           'year': 1,
#           'eur': 1,
#           '671': 1,
#           'million': 1}),
#  Counter({'compani': 1,
#           'negoti': 1,
#           'amend': 1,
#           'financi': 1,
#           'coven': 1,
#           'present': 1,
#           'credit': 1,
#           'agreement': 1,
#           'regard': 1,
#           'situat': 1,
#           '30': 1,
#           'septemb': 1,
#           '2010': 1}),
#  Counter({'ep': 1, 'improv': 1, 'eur0': 2, '38': 1, '27': 1}),
#  Counter({'expans': 1,
#           'aim': 1,
#           'attract': 1,
#           'new': 1,
#           'custom': 1,
#           'finland': 1,
#           'abroad': 1}),
#  Counter({'feder': 1,
#           'secretari': 1,
#           'transport': 1,
#           'commun': 1,
#           'mexico': 1,
#           'award': 1,
#           'poyri': 1,
#           'mexican': 1,
#           'partner': 1,
#           'sintra': 1,
#           'consult': 1,
#           'contract': 1,
#           'connect': 1,
#           'buenavistacuautitlan': 1,
#           'suburban': 1,
#           'railway': 1}),
#  Counter({'financi': 1,
#           'impact': 1,
#           'estim': 1,
#           'annual': 1,
#           'improv': 1,
#           'eur2': 1,
#           '0': 1,
#           'm': 1,
#           'divis': 1,
#           's': 1,
#           'result': 1,
#           'fiscal': 1,
#           'year': 1,
#           '2008': 1}),
#  Counter({'financi': 1,
#           'impact': 1,
#           'estim': 1,
#           '15': 1,
#           'meur': 1,
#           'annual': 1,
#           'improv': 1,
#           'divis': 1,
#           's': 1,
#           'result': 1,
#           'start': 1,
#           'fiscal': 1,
#           'year': 1,
#           '2007': 1}),
#  Counter({'finnish': 1,
#           'group': 1,
#           'anticip': 1,
#           'sale': 1,
#           'gain': 1,
#           'eur42m': 1,
#           'tax': 1,
#           'expens': 1}),
#  Counter({'launch': 1,
#           'plant': 1,
#           'june': 1,
#           'went': 1,
#           'well': 1,
#           'produc': 1,
#           'advanc': 1,
#           'fuel': 1,
#           'coupl': 1,
#           'week': 1}),
#  Counter({'parti': 1,
#           'agre': 1,
#           'negoti': 1,
#           'definit': 1,
#           'distribut': 1,
#           'licens': 1,
#           'agreement': 1,
#           'end': 1,
#           'june': 1,
#           '2010': 1}),
#  Counter({'ration': 1,
#           'oper': 1,
#           'seek': 1,
#           'achiev': 1,
#           'eur': 1,
#           '1': 1,
#           'million': 1,
#           'yearli': 1,
#           'save': 1,
#           'second': 1,
#           'quarter': 1,
#           'current': 1,
#           'financi': 1,
#           'year': 1}),
#  Counter({'sale': 1,
#           'will': 1,
#           'result': 1,
#           'gain': 1,
#           'eur': 1,
#           '60': 1,
#           'million': 1,
#           'second': 1,
#           'quarter': 1,
#           '2010': 1,
#           'oriolakd': 1,
#           'support': 1,
#           'finnish': 1,
#           'compani': 1,
#           's': 1,
#           'strategi': 1,
#           'focu': 1,
#           'pharmaceut': 1,
#           'wholesal': 1,
#           'retail': 1,
#           'oper': 1}),
#  Counter({'stock': 1,
#           'new': 2,
#           'machin': 1,
#           'reason': 1,
#           'small': 1,
#           'order': 1,
#           'bring': 1,
#           'work': 1}),
#  Counter({'third': 1,
#           'order': 1,
#           'award': 1,
#           'outokumpu': 1,
#           'technolog': 1,
#           'shalkiya': 2,
#           'zinc': 1,
#           'kazakhstan': 2,
#           'zinclead': 1,
#           'project': 1}),
#  Counter({'compani': 1,
#           'will': 1,
#           'abl': 1,
#           'keep': 1,
#           'market': 1,
#           'posit': 1}),
#  Counter({'acquisit': 1,
#           'support': 1,
#           'strategi': 1,
#           'close': 1,
#           'custom': 1,
#           'around': 1,
#           'world': 1,
#           'offer': 1,
#           'equip': 1,
#           'relat': 1,
#           'servic': 1}),
#  Counter({'lay': 1,
#           'foundat': 1,
#           'sustain': 1,
#           'busi': 1,
#           'develop': 1,
#           'long': 1,
#           'term': 1}),
#  Counter({'turun': 1,
#           'kaupunkin': 1,
#           'finland': 1,
#           'base': 1,
#           'compani': 1,
#           'award': 1,
#           'contract': 1,
#           'lemminkainen': 1,
#           'talotekniikka': 1,
#           'oy': 1,
#           'electr': 1,
#           'instal': 1,
#           'work': 1}),
#  Counter({'world': 1,
#           's': 2,
#           'biggest': 1,
#           'magazin': 1,
#           'paper': 1,
#           'maker': 1,
#           'said': 1,
#           'program': 1,
#           'improv': 1,
#           'effici': 1,
#           'will': 1,
#           'includ': 1,
#           'close': 1,
#           'sever': 1,
#           'least': 1,
#           'competit': 1,
#           'mill': 1,
#           'cover': 1,
#           'compani': 1,
#           'oper': 1,
#           'result': 1,
#           'annual': 1,
#           'save': 1,
#           'euro200': 1,
#           'million': 2,
#           'us': 1,
#           '240': 1}),
#  Counter({'moder': 1,
#           'signific': 2,
#           'chang': 1,
#           'result': 1,
#           '2432': 1,
#           'reduct': 1,
#           'estim': 1,
#           'cvd': 1,
#           'risk': 1}),
#  Counter({'uponor': 1,
#           'improv': 1,
#           'perform': 1,
#           'spite': 1,
#           'decreas': 1,
#           'residenti': 1,
#           'construct': 1,
#           'us': 1}),
#  Counter({'inventor': 1, 'issu': 1, 'us': 1, 'patent': 1}),
#  Counter({'isra': 1,
#           'cabl': 1,
#           'network': 1,
#           'oper': 1,
#           'hot': 1,
#           'telecom': 1,
#           'chosen': 1,
#           'telest': 2,
#           'intern': 1,
#           'technolog': 1,
#           'group': 1,
#           'exclus': 1,
#           'provid': 1,
#           'fttx': 1,
#           'equip': 1,
#           'israel': 1,
#           'accord': 1,
#           'today': 1}),
#  ...]

# %%
all_words_count = dict()
for counter in result[0]:
    for element in counter:
        all_words_count[element] = {"positive":0,"neutral":0,"negative":0}


for i in range(len(result[1])):
    sentiment =  result[1][i]
    for word in result[0][i]:
        all_words_count[word][sentiment]+=1
all_words_count
all_words_prob = dict()
sentiments = ["positive","neutral","negative"]
for word in all_words_count:
    all_words_prob[word] = dict()
    for sentiment in sentiments:
        all_words_prob[word][sentiment] = all_words_count[word][sentiment]/(all_words_count[word]["positive"]+all_words_count[word]["neutral"]+all_words_count[word]["negative"])
all_words_prob
# Out:
# {'accord': {'positive': 0.26548672566371684,
#   'neutral': 0.7079646017699115,
#   'negative': 0.02654867256637168},
#  'gran': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'compani': {'positive': 0.3206806282722513,
#   'neutral': 0.6492146596858639,
#   'negative': 0.030104712041884817},
#  'plan': {'positive': 0.3181818181818182,
#   'neutral': 0.6818181818181818,
#   'negative': 0.0},
#  'move': {'positive': 0.38461538461538464,
#   'neutral': 0.6153846153846154,
#   'negative': 0.0},
#  'product': {'positive': 0.2979591836734694,
#   'neutral': 0.6857142857142857,
#   'negative': 0.0163265306122449},
#  'russia': {'positive': 0.3684210526315789,
#   'neutral': 0.5921052631578947,
#   'negative': 0.039473684210526314},
#  'although': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'grow': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'technopoli': {'positive': 0.125, 'neutral': 0.875, 'negative': 0.0},
#  'develop': {'positive': 0.25806451612903225,
#   'neutral': 0.7311827956989247,
#   'negative': 0.010752688172043012},
#  'stage': {'positive': 0.09090909090909091,
#   'neutral': 0.9090909090909091,
#   'negative': 0.0},
#  'area': {'positive': 0.2911392405063291,
#   'neutral': 0.7088607594936709,
#   'negative': 0.0},
#  'less': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '100000': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'squar': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'meter': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'order': {'positive': 0.4925373134328358,
#   'neutral': 0.5074626865671642,
#   'negative': 0.0},
#  'host': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'work': {'positive': 0.2631578947368421,
#   'neutral': 0.7192982456140351,
#   'negative': 0.017543859649122806},
#  'comput': {'positive': 0.2,
#   'neutral': 0.7333333333333333,
#   'negative': 0.06666666666666667},
#  'technolog': {'positive': 0.423728813559322,
#   'neutral': 0.5677966101694916,
#   'negative': 0.00847457627118644},
#  'telecommun': {'positive': 0.35294117647058826,
#   'neutral': 0.6470588235294118,
#   'negative': 0.0},
#  'statement': {'positive': 0.22727272727272727,
#   'neutral': 0.7727272727272727,
#   'negative': 0.0},
#  'said': {'positive': 0.4976958525345622,
#   'neutral': 0.4539170506912442,
#   'negative': 0.04838709677419355},
#  'intern': {'positive': 0.2978723404255319,
#   'neutral': 0.6808510638297872,
#   'negative': 0.02127659574468085},
#  'electron': {'positive': 0.25925925925925924,
#   'neutral': 0.7222222222222222,
#   'negative': 0.018518518518518517},
#  'industri': {'positive': 0.275,
#   'neutral': 0.7083333333333334,
#   'negative': 0.016666666666666666},
#  'elcoteq': {'positive': 0.36363636363636365,
#   'neutral': 0.5454545454545454,
#   'negative': 0.09090909090909091},
#  'laid': {'positive': 0.0, 'neutral': 0.0, 'negative': 1.0},
#  'ten': {'positive': 0.3076923076923077,
#   'neutral': 0.5384615384615384,
#   'negative': 0.15384615384615385},
#  'employe': {'positive': 0.10294117647058823,
#   'neutral': 0.7352941176470589,
#   'negative': 0.16176470588235295},
#  'tallinn': {'positive': 0.5, 'neutral': 0.375, 'negative': 0.125},
#  'facil': {'positive': 0.24074074074074073,
#   'neutral': 0.7222222222222222,
#   'negative': 0.037037037037037035},
#  'contrari': {'positive': 0.0, 'neutral': 0.0, 'negative': 1.0},
#  'earlier': {'positive': 0.6226415094339622,
#   'neutral': 0.2830188679245283,
#   'negative': 0.09433962264150944},
#  'layoff': {'positive': 0.07142857142857142,
#   'neutral': 0.35714285714285715,
#   'negative': 0.5714285714285714},
#  'contract': {'positive': 0.4166666666666667,
#   'neutral': 0.532051282051282,
#   'negative': 0.05128205128205128},
#  'rank': {'positive': 0.5, 'neutral': 0.0, 'negative': 0.5},
#  'offic': {'positive': 0.18840579710144928,
#   'neutral': 0.7681159420289855,
#   'negative': 0.043478260869565216},
#  'worker': {'positive': 0.2222222222222222,
#   'neutral': 0.2222222222222222,
#   'negative': 0.5555555555555556},
#  'daili': {'positive': 0.1, 'neutral': 0.7, 'negative': 0.2},
#  'postime': {'positive': 0.0, 'neutral': 0.0, 'negative': 1.0},
#  'report': {'positive': 0.3333333333333333,
#   'neutral': 0.6491228070175439,
#   'negative': 0.017543859649122806},
#  'new': {'positive': 0.3274336283185841,
#   'neutral': 0.668141592920354,
#   'negative': 0.004424778761061947},
#  'plant': {'positive': 0.23931623931623933,
#   'neutral': 0.7094017094017094,
#   'negative': 0.05128205128205128},
#  'increas': {'positive': 0.8010471204188482,
#   'neutral': 0.18324607329842932,
#   'negative': 0.015706806282722512},
#  'capac': {'positive': 0.4222222222222222,
#   'neutral': 0.5555555555555556,
#   'negative': 0.022222222222222223},
#  'meet': {'positive': 0.17142857142857143,
#   'neutral': 0.8285714285714286,
#   'negative': 0.0},
#  'expect': {'positive': 0.4322033898305085,
#   'neutral': 0.5508474576271186,
#   'negative': 0.01694915254237288},
#  'demand': {'positive': 0.76, 'neutral': 0.24, 'negative': 0.0},
#  'improv': {'positive': 0.8703703703703703,
#   'neutral': 0.12962962962962962,
#   'negative': 0.0},
#  'use': {'positive': 0.20952380952380953,
#   'neutral': 0.7904761904761904,
#   'negative': 0.0},
#  'raw': {'positive': 0.3125, 'neutral': 0.6875, 'negative': 0.0},
#  'materi': {'positive': 0.24390243902439024,
#   'neutral': 0.7560975609756098,
#   'negative': 0.0},
#  'therefor': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'profit': {'positive': 0.7296296296296296,
#   'neutral': 0.21481481481481482,
#   'negative': 0.05555555555555555},
#  's': {'positive': 0.3490683229813665,
#   'neutral': 0.6335403726708074,
#   'negative': 0.017391304347826087},
#  'updat': {'positive': 0.375, 'neutral': 0.625, 'negative': 0.0},
#  'strategi': {'positive': 0.5142857142857142,
#   'neutral': 0.4857142857142857,
#   'negative': 0.0},
#  'year': {'positive': 0.6111111111111112,
#   'neutral': 0.3418803418803419,
#   'negative': 0.04700854700854701},
#  '20092012': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'baswar': {'positive': 0.3793103448275862,
#   'neutral': 0.6206896551724138,
#   'negative': 0.0},
#  'target': {'positive': 0.3181818181818182,
#   'neutral': 0.6363636363636364,
#   'negative': 0.045454545454545456},
#  'longterm': {'positive': 0.64, 'neutral': 0.32, 'negative': 0.04},
#  'net': {'positive': 0.6124567474048442,
#   'neutral': 0.35294117647058826,
#   'negative': 0.03460207612456748},
#  'sale': {'positive': 0.5163043478260869,
#   'neutral': 0.46195652173913043,
#   'negative': 0.021739130434782608},
#  'growth': {'positive': 0.6896551724137931,
#   'neutral': 0.25862068965517243,
#   'negative': 0.05172413793103448},
#  'rang': {'positive': 0.0967741935483871,
#   'neutral': 0.9032258064516129,
#   'negative': 0.0},
#  '20': {'positive': 0.3559322033898305,
#   'neutral': 0.5932203389830508,
#   'negative': 0.05084745762711865},
#  '40': {'positive': 0.4,
#   'neutral': 0.5333333333333333,
#   'negative': 0.06666666666666667},
#  'oper': {'positive': 0.45384615384615384,
#   'neutral': 0.5282051282051282,
#   'negative': 0.017948717948717947},
#  'margin': {'positive': 0.45, 'neutral': 0.45, 'negative': 0.1},
#  '10': {'positive': 0.3382352941176471,
#   'neutral': 0.6470588235294118,
#   'negative': 0.014705882352941176},
#  'financ': {'positive': 0.2857142857142857,
#   'neutral': 0.6785714285714286,
#   'negative': 0.03571428571428571},
#  'aspocomp': {'positive': 0.3333333333333333,
#   'neutral': 0.5555555555555556,
#   'negative': 0.1111111111111111},
#  'aggress': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'pursu': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'increasingli': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'focus': {'positive': 0.15384615384615385,
#   'neutral': 0.8461538461538461,
#   'negative': 0.0},
#  'hdi': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'print': {'positive': 0.35, 'neutral': 0.65, 'negative': 0.0},
#  'circuit': {'positive': 0.45454545454545453,
#   'neutral': 0.5454545454545454,
#   'negative': 0.0},
#  'board': {'positive': 0.2318840579710145,
#   'neutral': 0.7681159420289855,
#   'negative': 0.0},
#  'pcb': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'last': {'positive': 0.5735294117647058,
#   'neutral': 0.35294117647058826,
#   'negative': 0.07352941176470588},
#  'quarter': {'positive': 0.6083916083916084,
#   'neutral': 0.3146853146853147,
#   'negative': 0.07692307692307693},
#  '2010': {'positive': 0.5409836065573771,
#   'neutral': 0.41530054644808745,
#   'negative': 0.04371584699453552},
#  'componenta': {'positive': 0.45, 'neutral': 0.5, 'negative': 0.05},
#  'doubl': {'positive': 0.9375, 'neutral': 0.0625, 'negative': 0.0},
#  'eur131m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur76m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'period': {'positive': 0.7483870967741936,
#   'neutral': 0.17419354838709677,
#   'negative': 0.07741935483870968},
#  'zero': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'pretax': {'positive': 0.8076923076923077,
#   'neutral': 0.07692307692307693,
#   'negative': 0.11538461538461539},
#  'loss': {'positive': 0.7325581395348837,
#   'neutral': 0.08139534883720931,
#   'negative': 0.18604651162790697},
#  'eur7m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'third': {'positive': 0.6086956521739131,
#   'neutral': 0.34782608695652173,
#   'negative': 0.043478260869565216},
#  '52': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'eur': {'positive': 0.5353982300884956,
#   'neutral': 0.413716814159292,
#   'negative': 0.05088495575221239},
#  '2055': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'mn': {'positive': 0.7090909090909091,
#   'neutral': 0.23030303030303031,
#   'negative': 0.06060606060606061},
#  '349': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '235': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'rose': {'positive': 0.9489795918367347,
#   'neutral': 0.02040816326530612,
#   'negative': 0.030612244897959183},
#  '131': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  '87': {'positive': 0.4, 'neutral': 0.6, 'negative': 0.0},
#  'correspond': {'positive': 0.7654320987654321,
#   'neutral': 0.16049382716049382,
#   'negative': 0.07407407407407407},
#  '2007': {'positive': 0.4251497005988024,
#   'neutral': 0.5389221556886228,
#   'negative': 0.03592814371257485},
#  'repres': {'positive': 0.4166666666666667,
#   'neutral': 0.5833333333333334,
#   'negative': 0.0},
#  '77': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'total': {'positive': 0.29545454545454547,
#   'neutral': 0.6590909090909091,
#   'negative': 0.045454545454545456},
#  '211': {'positive': 0.5, 'neutral': 0.0, 'negative': 0.5},
#  '186': {'positive': 0.8, 'neutral': 0.2, 'negative': 0.0},
#  '97': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'teliasonera': {'positive': 0.2916666666666667,
#   'neutral': 0.6666666666666666,
#   'negative': 0.041666666666666664},
#  'tlsn': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'offer': {'positive': 0.325, 'neutral': 0.675, 'negative': 0.0},
#  'line': {'positive': 0.421875, 'neutral': 0.578125, 'negative': 0.0},
#  'ownership': {'positive': 0.18181818181818182,
#   'neutral': 0.8181818181818182,
#   'negative': 0.0},
#  'core': {'positive': 0.4666666666666667,
#   'neutral': 0.5333333333333333,
#   'negative': 0.0},
#  'busi': {'positive': 0.2674897119341564,
#   'neutral': 0.7283950617283951,
#   'negative': 0.00411522633744856},
#  'hold': {'positive': 0.24561403508771928,
#   'neutral': 0.7368421052631579,
#   'negative': 0.017543859649122806},
#  'strengthen': {'positive': 0.78125, 'neutral': 0.1875, 'negative': 0.03125},
#  'eesti': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'telekom': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'custom': {'positive': 0.3230769230769231,
#   'neutral': 0.6692307692307692,
#   'negative': 0.007692307692307693},
#  'stora': {'positive': 0.3448275862068966,
#   'neutral': 0.5862068965517241,
#   'negative': 0.06896551724137931},
#  'enso': {'positive': 0.3333333333333333,
#   'neutral': 0.5925925925925926,
#   'negative': 0.07407407407407407},
#  'norsk': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'skog': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'mreal': {'positive': 0.3333333333333333,
#   'neutral': 0.6190476190476191,
#   'negative': 0.047619047619047616},
#  'upmkymmen': {'positive': 0.6428571428571429,
#   'neutral': 0.2857142857142857,
#   'negative': 0.07142857142857142},
#  'credit': {'positive': 0.23076923076923078,
#   'neutral': 0.7692307692307693,
#   'negative': 0.0},
#  'suiss': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'first': {'positive': 0.5079365079365079,
#   'neutral': 0.42857142857142855,
#   'negative': 0.06349206349206349},
#  'boston': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'cfsb': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'rais': {'positive': 0.64, 'neutral': 0.32, 'negative': 0.04},
#  'fair': {'positive': 0.4666666666666667,
#   'neutral': 0.5333333333333333,
#   'negative': 0.0},
#  'valu': {'positive': 0.17307692307692307,
#   'neutral': 0.8173076923076923,
#   'negative': 0.009615384615384616},
#  'share': {'positive': 0.26595744680851063,
#   'neutral': 0.7269503546099291,
#   'negative': 0.0070921985815602835},
#  'four': {'positive': 0.41379310344827586,
#   'neutral': 0.5517241379310345,
#   'negative': 0.034482758620689655},
#  'largest': {'positive': 0.3829787234042553,
#   'neutral': 0.5957446808510638,
#   'negative': 0.02127659574468085},
#  'nordic': {'positive': 0.30952380952380953,
#   'neutral': 0.6904761904761905,
#   'negative': 0.0},
#  'forestri': {'positive': 0.625, 'neutral': 0.375, 'negative': 0.0},
#  'group': {'positive': 0.3435114503816794,
#   'neutral': 0.6259541984732825,
#   'negative': 0.030534351145038167},
#  'purchas': {'positive': 0.21052631578947367,
#   'neutral': 0.7631578947368421,
#   'negative': 0.02631578947368421},
#  'agreement': {'positive': 0.5357142857142857,
#   'neutral': 0.4642857142857143,
#   'negative': 0.0},
#  '7200': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ton': {'positive': 0.1111111111111111,
#   'neutral': 0.8888888888888888,
#   'negative': 0.0},
#  'gasolin': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'deliveri': {'positive': 0.22, 'neutral': 0.78, 'negative': 0.0},
#  'hamina': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'termin': {'positive': 0.2,
#   'neutral': 0.5333333333333333,
#   'negative': 0.26666666666666666},
#  'finland': {'positive': 0.26394052044609667,
#   'neutral': 0.6802973977695167,
#   'negative': 0.055762081784386616},
#  'sign': {'positive': 0.7349397590361446,
#   'neutral': 0.26506024096385544,
#   'negative': 0.0},
#  'nest': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'oil': {'positive': 0.3142857142857143,
#   'neutral': 0.6571428571428571,
#   'negative': 0.02857142857142857},
#  'oyj': {'positive': 0.5222222222222223,
#   'neutral': 0.40555555555555556,
#   'negative': 0.07222222222222222},
#  'averag': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'platt': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'index': {'positive': 0.4666666666666667,
#   'neutral': 0.4,
#   'negative': 0.13333333333333333},
#  'septemb': {'positive': 0.3404255319148936,
#   'neutral': 0.6595744680851063,
#   'negative': 0.0},
#  'plu': {'positive': 0.2222222222222222,
#   'neutral': 0.7777777777777778,
#   'negative': 0.0},
#  'eight': {'positive': 0.2857142857142857,
#   'neutral': 0.5714285714285714,
#   'negative': 0.14285714285714285},
#  'us': {'positive': 0.3918918918918919,
#   'neutral': 0.6081081081081081,
#   'negative': 0.0},
#  'dollar': {'positive': 0.375, 'neutral': 0.5, 'negative': 0.125},
#  'per': {'positive': 0.4418604651162791,
#   'neutral': 0.5348837209302325,
#   'negative': 0.023255813953488372},
#  'month': {'positive': 0.6,
#   'neutral': 0.3333333333333333,
#   'negative': 0.06666666666666667},
#  'finnish': {'positive': 0.4847715736040609,
#   'neutral': 0.467005076142132,
#   'negative': 0.048223350253807105},
#  'talentum': {'positive': 0.4444444444444444,
#   'neutral': 0.5555555555555556,
#   'negative': 0.0},
#  '205': {'positive': 0.3333333333333333,
#   'neutral': 0.3333333333333333,
#   'negative': 0.3333333333333333},
#  '2005': {'positive': 0.6103896103896104,
#   'neutral': 0.37662337662337664,
#   'negative': 0.012987012987012988},
#  '93': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '2004': {'positive': 0.6333333333333333,
#   'neutral': 0.36666666666666664,
#   'negative': 0.0},
#  '1033': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '964': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'cloth': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'retail': {'positive': 0.34782608695652173,
#   'neutral': 0.6304347826086957,
#   'negative': 0.021739130434782608},
#  'chain': {'positive': 0.41935483870967744,
#   'neutral': 0.5806451612903226,
#   'negative': 0.0},
#  'sepp�l�': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '8': {'positive': 0.46153846153846156,
#   'neutral': 0.5128205128205128,
#   'negative': 0.02564102564102564},
#  '1552': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '311': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '171': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'consolid': {'positive': 0.3888888888888889,
#   'neutral': 0.6111111111111112,
#   'negative': 0.0},
#  '16': {'positive': 0.34782608695652173,
#   'neutral': 0.5652173913043478,
#   'negative': 0.08695652173913043},
#  'reach': {'positive': 0.625,
#   'neutral': 0.3333333333333333,
#   'negative': 0.041666666666666664},
#  'eur74': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'm': {'positive': 0.5641025641025641,
#   'neutral': 0.391025641025641,
#   'negative': 0.04487179487179487},
#  'amount': {'positive': 0.21875, 'neutral': 0.71875, 'negative': 0.0625},
#  'eur0': {'positive': 0.6896551724137931,
#   'neutral': 0.3103448275862069,
#   'negative': 0.0},
#  '9': {'positive': 0.5277777777777778,
#   'neutral': 0.4444444444444444,
#   'negative': 0.027777777777777776},
#  'compar': {'positive': 0.8222222222222222,
#   'neutral': 0.1,
#   'negative': 0.07777777777777778},
#  '7': {'positive': 0.5675675675675675,
#   'neutral': 0.40540540540540543,
#   'negative': 0.02702702702702703},
#  'prior': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'foundri': {'positive': 0.4, 'neutral': 0.4, 'negative': 0.2},
#  'divis': {'positive': 0.28205128205128205,
#   'neutral': 0.6923076923076923,
#   'negative': 0.02564102564102564},
#  '631': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '575': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '2006': {'positive': 0.463768115942029,
#   'neutral': 0.5289855072463768,
#   'negative': 0.007246376811594203},
#  'machin': {'positive': 0.5185185185185185,
#   'neutral': 0.48148148148148145,
#   'negative': 0.0},
#  'shop': {'positive': 0.36363636363636365,
#   'neutral': 0.6363636363636364,
#   'negative': 0.0},
#  '164': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '412': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '354': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'helsinki': {'positive': 0.27586206896551724,
#   'neutral': 0.7155172413793104,
#   'negative': 0.008620689655172414},
#  'afx': {'positive': 0.5294117647058824,
#   'neutral': 0.47058823529411764,
#   'negative': 0.0},
#  'close': {'positive': 0.2558139534883721,
#   'neutral': 0.6744186046511628,
#   'negative': 0.06976744186046512},
#  'higher': {'positive': 0.7619047619047619,
#   'neutral': 0.23809523809523808,
#   'negative': 0.0},
#  'led': {'positive': 0.2, 'neutral': 0.8, 'negative': 0.0},
#  'nokia': {'positive': 0.35106382978723405,
#   'neutral': 0.648936170212766,
#   'negative': 0.0},
#  'announc': {'positive': 0.2875, 'neutral': 0.6875, 'negative': 0.025},
#  'team': {'positive': 0.4, 'neutral': 0.6, 'negative': 0.0},
#  'sanyo': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'manufactur': {'positive': 0.2903225806451613,
#   'neutral': 0.6854838709677419,
#   'negative': 0.024193548387096774},
#  '3g': {'positive': 0.5555555555555556,
#   'neutral': 0.4444444444444444,
#   'negative': 0.0},
#  'handset': {'positive': 0.30434782608695654,
#   'neutral': 0.6956521739130435,
#   'negative': 0.0},
#  'nokian': {'positive': 0.7, 'neutral': 0.3, 'negative': 0.0},
#  'tyre': {'positive': 0.5454545454545454,
#   'neutral': 0.45454545454545453,
#   'negative': 0.0},
#  'fourthquart': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'earn': {'positive': 0.725, 'neutral': 0.225, 'negative': 0.05},
#  'beat': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'analyst': {'positive': 0.2727272727272727,
#   'neutral': 0.6363636363636364,
#   'negative': 0.09090909090909091},
#  'dealer': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'incap': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'servic': {'positive': 0.31297709923664124,
#   'neutral': 0.683206106870229,
#   'negative': 0.003816793893129771},
#  'pvt': {'positive': 0.2, 'neutral': 0.8, 'negative': 0.0},
#  'ltd': {'positive': 0.3191489361702128,
#   'neutral': 0.6808510638297872,
#   'negative': 0.0},
#  'subsidiari': {'positive': 0.2830188679245283,
#   'neutral': 0.7169811320754716,
#   'negative': 0.0},
#  'corpor': {'positive': 0.35537190082644626,
#   'neutral': 0.628099173553719,
#   'negative': 0.01652892561983471},
#  'revenu': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '20072008': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'director': {'positive': 0.3484848484848485,
#   'neutral': 0.6363636363636364,
#   'negative': 0.015151515151515152},
#  'will': {'positive': 0.2369186046511628,
#   'neutral': 0.7194767441860465,
#   'negative': 0.0436046511627907},
#  'propos': {'positive': 0.24242424242424243,
#   'neutral': 0.7272727272727273,
#   'negative': 0.030303030303030304},
#  'dividend': {'positive': 0.19444444444444445,
#   'neutral': 0.8055555555555556,
#   'negative': 0.0},
#  '12': {'positive': 0.4418604651162791,
#   'neutral': 0.5348837209302325,
#   'negative': 0.023255813953488372},
#  '08': {'positive': 0.7142857142857143,
#   'neutral': 0.2857142857142857,
#   'negative': 0.0},
#  'paid': {'positive': 0.17647058823529413,
#   'neutral': 0.8235294117647058,
#   'negative': 0.0},
#  '2009': {'positive': 0.48292682926829267,
#   'neutral': 0.43414634146341463,
#   'negative': 0.08292682926829269},
#  'lifetre': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'found': {'positive': 0.17647058823529413,
#   'neutral': 0.8235294117647058,
#   'negative': 0.0},
#  '2000': {'positive': 0.125, 'neutral': 0.875, 'negative': 0.0},
#  'risen': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'late': {'positive': 0.2857142857142857,
#   'neutral': 0.7142857142857143,
#   'negative': 0.0},
#  '30': {'positive': 0.46808510638297873,
#   'neutral': 0.5319148936170213,
#   'negative': 0.0},
#  'filippova': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'trilater': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'invest': {'positive': 0.26811594202898553,
#   'neutral': 0.7246376811594203,
#   'negative': 0.007246376811594203},
#  'construct': {'positive': 0.28865979381443296,
#   'neutral': 0.6907216494845361,
#   'negative': 0.020618556701030927},
#  'park': {'positive': 0.125, 'neutral': 0.875, 'negative': 0.0},
#  'st': {'positive': 0.37037037037037035,
#   'neutral': 0.5925925925925926,
#   'negative': 0.037037037037037035},
#  'petersburg': {'positive': 0.44, 'neutral': 0.56, 'negative': 0.0},
#  'cours': {'positive': 0.2222222222222222,
#   'neutral': 0.7777777777777778,
#   'negative': 0.0},
#  'forum': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'day': {'positive': 0.21428571428571427,
#   'neutral': 0.6785714285714286,
#   'negative': 0.10714285714285714},
#  'russian': {'positive': 0.3793103448275862,
#   'neutral': 0.6206896551724138,
#   'negative': 0.0},
#  'economi': {'positive': 0.4, 'neutral': 0.6, 'negative': 0.0},
#  'open': {'positive': 0.4838709677419355,
#   'neutral': 0.5161290322580645,
#   'negative': 0.0},
#  'today': {'positive': 0.5,
#   'neutral': 0.4067796610169492,
#   'negative': 0.09322033898305085},
#  'megafon': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'subscrib': {'positive': 0.038461538461538464,
#   'neutral': 0.9615384615384616,
#   'negative': 0.0},
#  'base': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  '161': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '505': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'million': {'positive': 0.444015444015444,
#   'neutral': 0.525096525096525,
#   'negative': 0.03088803088803089},
#  'user': {'positive': 0.24, 'neutral': 0.72, 'negative': 0.04},
#  'decemb': {'positive': 0.6086956521739131,
#   'neutral': 0.34782608695652173,
#   'negative': 0.043478260869565216},
#  '31': {'positive': 0.5833333333333334,
#   'neutral': 0.375,
#   'negative': 0.041666666666666664},
#  'market': {'positive': 0.3237704918032787,
#   'neutral': 0.6639344262295082,
#   'negative': 0.012295081967213115},
#  'number': {'positive': 0.16071428571428573,
#   'neutral': 0.7678571428571429,
#   'negative': 0.07142857142857142},
#  '24': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '23': {'positive': 0.41379310344827586,
#   'neutral': 0.5517241379310345,
#   'negative': 0.034482758620689655},
#  '2008': {'positive': 0.3812154696132597,
#   'neutral': 0.569060773480663,
#   'negative': 0.049723756906077346},
#  'estim': {'positive': 0.46774193548387094,
#   'neutral': 0.5161290322580645,
#   'negative': 0.016129032258064516},
#  'incom': {'positive': 0.6842105263157895,
#   'neutral': 0.3157894736842105,
#   'negative': 0.0},
#  'life': {'positive': 0.375, 'neutral': 0.625, 'negative': 0.0},
#  'insur': {'positive': 0.4166666666666667,
#   'neutral': 0.5,
#   'negative': 0.08333333333333333},
#  '68': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '32': {'positive': 0.6363636363636364,
#   'neutral': 0.18181818181818182,
#   'negative': 0.18181818181818182},
#  'nonlif': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '15': {'positive': 0.4, 'neutral': 0.58, 'negative': 0.02},
#  'eur193': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '3': {'positive': 0.48214285714285715,
#   'neutral': 0.44642857142857145,
#   'negative': 0.07142857142857142},
#  'eur179': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '342': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur43': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '1': {'positive': 0.44285714285714284,
#   'neutral': 0.5428571428571428,
#   'negative': 0.014285714285714285},
#  'eur1': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'usd1': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '4': {'positive': 0.4782608695652174,
#   'neutral': 0.5,
#   'negative': 0.021739130434782608},
#  'surg': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '185': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'eur167': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'telest': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'eur20': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '122': {'positive': 0.8, 'neutral': 0.2, 'negative': 0.0},
#  'came': {'positive': 0.5384615384615384,
#   'neutral': 0.46153846153846156,
#   'negative': 0.0},
#  'acquisit': {'positive': 0.3918918918918919,
#   'neutral': 0.6081081081081081,
#   'negative': 0.0},
#  'made': {'positive': 0.19047619047619047,
#   'neutral': 0.8095238095238095,
#   'negative': 0.0},
#  'nordea': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  '18': {'positive': 0.5769230769230769,
#   'neutral': 0.38461538461538464,
#   'negative': 0.038461538461538464},
#  'percent': {'positive': 0.6575342465753424,
#   'neutral': 0.3424657534246575,
#   'negative': 0.0},
#  'yearonyear': {'positive': 0.9615384615384616,
#   'neutral': 0.0,
#   'negative': 0.038461538461538464},
#  '364': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'billion': {'positive': 0.358974358974359,
#   'neutral': 0.6153846153846154,
#   'negative': 0.02564102564102564},
#  'euro': {'positive': 0.43703703703703706,
#   'neutral': 0.5481481481481482,
#   'negative': 0.014814814814814815},
#  '933': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ninemonth': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur13': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '6': {'positive': 0.5609756097560976,
#   'neutral': 0.36585365853658536,
#   'negative': 0.07317073170731707},
#  'eur394': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur3': {'positive': 0.6363636363636364,
#   'neutral': 0.36363636363636365,
#   'negative': 0.0},
#  'eur61': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '5': {'positive': 0.39215686274509803,
#   'neutral': 0.5490196078431373,
#   'negative': 0.058823529411764705},
#  'threemonth': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '2': {'positive': 0.4230769230769231,
#   'neutral': 0.5384615384615384,
#   'negative': 0.038461538461538464},
#  'brazilian': {'positive': 0.8333333333333334,
#   'neutral': 0.16666666666666666,
#   'negative': 0.0},
#  'unit': {'positive': 0.21495327102803738,
#   'neutral': 0.7476635514018691,
#   'negative': 0.037383177570093455},
#  'secur': {'positive': 0.3125, 'neutral': 0.6875, 'negative': 0.0},
#  'solut': {'positive': 0.38848920863309355,
#   'neutral': 0.5971223021582733,
#   'negative': 0.014388489208633094},
#  'provid': {'positive': 0.3698630136986301,
#   'neutral': 0.6027397260273972,
#   'negative': 0.0273972602739726},
#  'fsecur': {'positive': 0.25,
#   'neutral': 0.6666666666666666,
#   'negative': 0.08333333333333333},
#  '1500': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'client': {'positive': 0.3684210526315789,
#   'neutral': 0.631578947368421,
#   'negative': 0.0},
#  'onlin': {'positive': 0.23809523809523808,
#   'neutral': 0.7619047619047619,
#   'negative': 0.0},
#  'news': {'positive': 0.5,
#   'neutral': 0.45454545454545453,
#   'negative': 0.045454545454545456},
#  'sourc': {'positive': 0.07142857142857142,
#   'neutral': 0.9285714285714286,
#   'negative': 0.0},
#  'resel': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'web': {'positive': 0.2, 'neutral': 0.8, 'negative': 0.0},
#  'quot': {'positive': 0.125, 'neutral': 0.875, 'negative': 0.0},
#  'commerci': {'positive': 0.3,
#   'neutral': 0.6666666666666666,
#   'negative': 0.03333333333333333},
#  'vladimir': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'brando': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'say': {'positive': 0.5454545454545454,
#   'neutral': 0.45454545454545453,
#   'negative': 0.0},
#  '114': {'positive': 0.7777777777777778,
#   'neutral': 0.1111111111111111,
#   'negative': 0.1111111111111111},
#  '822': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '6865': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '138': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'lithuanian': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'beer': {'positive': 0.65, 'neutral': 0.3, 'negative': 0.05},
#  '1441': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'liter': {'positive': 0.8571428571428571,
#   'neutral': 0.14285714285714285,
#   'negative': 0.0},
#  'januari': {'positive': 0.16666666666666666,
#   'neutral': 0.7708333333333334,
#   'negative': 0.0625},
#  'rise': {'positive': 0.7894736842105263,
#   'neutral': 0.15789473684210525,
#   'negative': 0.05263157894736842},
#  'yearearli': {'positive': 0.75, 'neutral': 0.0, 'negative': 0.25},
#  'figur': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'brewer': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'associ': {'positive': 0.3888888888888889,
#   'neutral': 0.6111111111111112,
#   'negative': 0.0},
#  'cite': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'result': {'positive': 0.3875, 'neutral': 0.4625, 'negative': 0.15},
#  'member': {'positive': 0.26666666666666666,
#   'neutral': 0.7333333333333333,
#   'negative': 0.0},
#  'vike': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'cargo': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '54': {'positive': 0.3333333333333333,
#   'neutral': 0.5,
#   'negative': 0.16666666666666666},
#  '2146': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'volum': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '70116': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'properti': {'positive': 0.21875, 'neutral': 0.78125, 'negative': 0.0},
#  'portfolio': {'positive': 0.38095238095238093,
#   'neutral': 0.6190476190476191,
#   'negative': 0.0},
#  'kapite': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '26862': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '12597': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'februari': {'positive': 0.4411764705882353,
#   'neutral': 0.5,
#   'negative': 0.058823529411764705},
#  '2011': {'positive': 0.3968253968253968,
#   'neutral': 0.5873015873015873,
#   'negative': 0.015873015873015872},
#  'media': {'positive': 0.09090909090909091,
#   'neutral': 0.8909090909090909,
#   'negative': 0.01818181818181818},
#  'sanoma': {'positive': 0.14285714285714285,
#   'neutral': 0.8095238095238095,
#   'negative': 0.047619047619047616},
#  'hel': {'positive': 0.5393258426966292,
#   'neutral': 0.34831460674157305,
#   'negative': 0.11235955056179775},
#  'saa1v': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'yesterday': {'positive': 0.43478260869565216,
#   'neutral': 0.5652173913043478,
#   'negative': 0.0},
#  'almost': {'positive': 0.3076923076923077,
#   'neutral': 0.6923076923076923,
#   'negative': 0.0},
#  'tripl': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur297': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur107': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'payout': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eliiv': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ep': {'positive': 0.8620689655172413,
#   'neutral': 0.13793103448275862,
#   'negative': 0.0},
#  '13': {'positive': 0.56, 'neutral': 0.32, 'negative': 0.12},
#  'aspo': {'positive': 0.2727272727272727,
#   'neutral': 0.7272727272727273,
#   'negative': 0.0},
#  'plc': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'stock': {'positive': 0.28, 'neutral': 0.68, 'negative': 0.04},
#  'exchang': {'positive': 0.1896551724137931,
#   'neutral': 0.7931034482758621,
#   'negative': 0.017241379310344827},
#  'releas': {'positive': 0.3392857142857143,
#   'neutral': 0.6428571428571429,
#   'negative': 0.017857142857142856},
#  '11': {'positive': 0.3448275862068966,
#   'neutral': 0.5862068965517241,
#   'negative': 0.06896551724137931},
#  'at8': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '45': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'esl': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'ship': {'positive': 0.3076923076923077,
#   'neutral': 0.6923076923076923,
#   'negative': 0.0},
#  'part': {'positive': 0.1875, 'neutral': 0.7875, 'negative': 0.025},
#  'rautaruukki': {'positive': 0.4444444444444444,
#   'neutral': 0.3333333333333333,
#   'negative': 0.2222222222222222},
#  'marin': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'transport': {'positive': 0.4166666666666667,
#   'neutral': 0.5833333333333334,
#   'negative': 0.0},
#  'baltic': {'positive': 0.38235294117647056,
#   'neutral': 0.5882352941176471,
#   'negative': 0.029411764705882353},
#  'sea': {'positive': 0.25, 'neutral': 0.625, 'negative': 0.125},
#  'commiss': {'positive': 0.21428571428571427,
#   'neutral': 0.7857142857142857,
#   'negative': 0.0},
#  '22': {'positive': 0.32, 'neutral': 0.6, 'negative': 0.08},
#  '44': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'lend': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '135': {'positive': 0.2, 'neutral': 0.8, 'negative': 0.0},
#  'traffic': {'positive': 0.34782608695652173,
#   'neutral': 0.6086956521739131,
#   'negative': 0.043478260869565216},
#  'measur': {'positive': 0.30952380952380953,
#   'neutral': 0.6428571428571429,
#   'negative': 0.047619047619047616},
#  'passeng': {'positive': 0.7333333333333333,
#   'neutral': 0.2,
#   'negative': 0.06666666666666667},
#  'kilometr': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'rpk': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'went': {'positive': 0.8461538461538461,
#   'neutral': 0.15384615384615385,
#   'negative': 0.0},
#  'avail': {'positive': 0.13513513513513514,
#   'neutral': 0.8648648648648649,
#   'negative': 0.0},
#  'seat': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'ask': {'positive': 0.16666666666666666,
#   'neutral': 0.8333333333333334,
#   'negative': 0.0},
#  'januaryseptemb': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'fiskar': {'positive': 0.52, 'neutral': 0.48, 'negative': 0.0},
#  '14': {'positive': 0.4074074074074074,
#   'neutral': 0.5555555555555556,
#   'negative': 0.037037037037037035},
#  '654': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '5253': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '4877': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '165': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '140': {'positive': 0.2857142857142857,
#   'neutral': 0.5714285714285714,
#   'negative': 0.14285714285714285},
#  '226': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '152': {'positive': 0.5, 'neutral': 0.0, 'negative': 0.5},
#  'nyrstar': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'also': {'positive': 0.2916666666666667,
#   'neutral': 0.6666666666666666,
#   'negative': 0.041666666666666664},
#  'agre': {'positive': 0.3076923076923077,
#   'neutral': 0.6666666666666666,
#   'negative': 0.02564102564102564},
#  'suppli': {'positive': 0.532258064516129,
#   'neutral': 0.45161290322580644,
#   'negative': 0.016129032258064516},
#  'talvivaara': {'positive': 0.5,
#   'neutral': 0.42857142857142855,
#   'negative': 0.07142857142857142},
#  '150000': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'tonn': {'positive': 0.3888888888888889,
#   'neutral': 0.6111111111111112,
#   'negative': 0.0},
#  'sulphur': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'acid': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'annum': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'leach': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'process': {'positive': 0.30985915492957744,
#   'neutral': 0.6901408450704225,
#   'negative': 0.0},
#  'zinc': {'positive': 0.8333333333333334,
#   'neutral': 0.16666666666666666,
#   'negative': 0.0},
#  'concentr': {'positive': 0.2727272727272727,
#   'neutral': 0.7272727272727273,
#   'negative': 0.0},
#  'depart': {'positive': 0.6153846153846154,
#   'neutral': 0.38461538461538464,
#   'negative': 0.0},
#  'store': {'positive': 0.27906976744186046,
#   'neutral': 0.6976744186046512,
#   'negative': 0.023255813953488372},
#  'hobbi': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'hall': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'seppala': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'decreas': {'positive': 0.3333333333333333,
#   'neutral': 0.26666666666666666,
#   'negative': 0.4},
#  'export': {'positive': 0.32, 'neutral': 0.68, 'negative': 0.0},
#  'due': {'positive': 0.34782608695652173,
#   'neutral': 0.4782608695652174,
#   'negative': 0.17391304347826086},
#  'rate': {'positive': 0.39473684210526316,
#   'neutral': 0.5526315789473685,
#   'negative': 0.05263157894736842},
#  'partnership': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'siemen': {'positive': 0.4666666666666667,
#   'neutral': 0.5333333333333333,
#   'negative': 0.0},
#  'network': {'positive': 0.35294117647058826,
#   'neutral': 0.6470588235294118,
#   'negative': 0.0},
#  'biohit': {'positive': 0.5,
#   'neutral': 0.4166666666666667,
#   'negative': 0.08333333333333333},
#  'healthcar': {'positive': 0.2857142857142857,
#   'neutral': 0.7142857142857143,
#   'negative': 0.0},
#  'ukbas': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'public': {'positive': 0.2608695652173913,
#   'neutral': 0.7391304347826086,
#   'negative': 0.0},
#  'liquid': {'positive': 0.26666666666666666,
#   'neutral': 0.6666666666666666,
#   'negative': 0.06666666666666667},
#  'handl': {'positive': 0.5625, 'neutral': 0.4375, 'negative': 0.0},
#  'diagnost': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'test': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'system': {'positive': 0.34782608695652173,
#   'neutral': 0.6086956521739131,
#   'negative': 0.043478260869565216},
#  'alreadi': {'positive': 0.2647058823529412,
#   'neutral': 0.6764705882352942,
#   'negative': 0.058823529411764705},
#  'carri': {'positive': 0.28, 'neutral': 0.68, 'negative': 0.04},
#  'lead': {'positive': 0.5576923076923077,
#   'neutral': 0.4423076923076923,
#   'negative': 0.0},
#  '1417': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'book': {'positive': 0.4444444444444444,
#   'neutral': 0.5555555555555556,
#   'negative': 0.0},
#  'stood': {'positive': 0.45454545454545453,
#   'neutral': 0.45454545454545453,
#   'negative': 0.09090909090909091},
#  'bln': {'positive': 0.5, 'neutral': 0.25, 'negative': 0.25},
#  '242': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'pct': {'positive': 0.4318181818181818,
#   'neutral': 0.5,
#   'negative': 0.06818181818181818},
#  '365': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'mln': {'positive': 0.5428571428571428,
#   'neutral': 0.41904761904761906,
#   'negative': 0.0380952380952381},
#  '5343': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'paper': {'positive': 0.3333333333333333,
#   'neutral': 0.6515151515151515,
#   'negative': 0.015151515151515152},
#  'main': {'positive': 0.36, 'neutral': 0.64, 'negative': 0.0},
#  'includ': {'positive': 0.1329479768786127,
#   'neutral': 0.861271676300578,
#   'negative': 0.005780346820809248},
#  'price': {'positive': 0.3253012048192771,
#   'neutral': 0.6385542168674698,
#   'negative': 0.03614457831325301},
#  'world': {'positive': 0.4318181818181818,
#   'neutral': 0.5681818181818182,
#   'negative': 0.0},
#  'second': {'positive': 0.49206349206349204,
#   'neutral': 0.47619047619047616,
#   'negative': 0.031746031746031744},
#  'stainless': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'steel': {'positive': 0.45454545454545453,
#   'neutral': 0.4318181818181818,
#   'negative': 0.11363636363636363},
#  'maker': {'positive': 0.6229508196721312,
#   'neutral': 0.29508196721311475,
#   'negative': 0.08196721311475409},
#  'dec': {'positive': 0.3, 'neutral': 0.7, 'negative': 0.0},
#  'euro603': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '781': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'euro3': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '33': {'positive': 0.35294117647058826,
#   'neutral': 0.5882352941176471,
#   'negative': 0.058823529411764705},
#  '431': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'euro172': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'euro0': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '94': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'previou': {'positive': 0.5238095238095238,
#   'neutral': 0.2857142857142857,
#   'negative': 0.19047619047619047},
#  'within': {'positive': 0.1111111111111111,
#   'neutral': 0.8888888888888888,
#   'negative': 0.0},
#  'framework': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'initi': {'positive': 0.36363636363636365,
#   'neutral': 0.6363636363636364,
#   'negative': 0.0},
#  'sitron': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'jsc': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'mikron': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'microelectron': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'compon': {'positive': 0.35714285714285715,
#   'neutral': 0.6428571428571429,
#   'negative': 0.0},
#  '02': {'positive': 0.42857142857142855,
#   'neutral': 0.42857142857142855,
#   'negative': 0.14285714285714285},
#  'eur10': {'positive': 0.8, 'neutral': 0.2, 'negative': 0.0},
#  'eur6': {'positive': 0.6666666666666666,
#   'neutral': 0.16666666666666666,
#   'negative': 0.16666666666666666},
#  'abroad': {'positive': 0.42857142857142855,
#   'neutral': 0.42857142857142855,
#   'negative': 0.14285714285714285},
#  '62': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'countri': {'positive': 0.2923076923076923,
#   'neutral': 0.676923076923077,
#   'negative': 0.03076923076923077},
#  'well': {'positive': 0.2222222222222222,
#   'neutral': 0.7676767676767676,
#   'negative': 0.010101010101010102},
#  'ukrain': {'positive': 0.375, 'neutral': 0.625, 'negative': 0.0},
#  'standard': {'positive': 0.38461538461538464,
#   'neutral': 0.6153846153846154,
#   'negative': 0.0},
#  'charter': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'stan': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ftse': {'positive': 0.3333333333333333,
#   'neutral': 0.3333333333333333,
#   'negative': 0.3333333333333333},
#  '100': {'positive': 0.41379310344827586,
#   'neutral': 0.5172413793103449,
#   'negative': 0.06896551724137931},
#  'royal': {'positive': 0.6, 'neutral': 0.2, 'negative': 0.2},
#  'bank': {'positive': 0.30927835051546393,
#   'neutral': 0.6804123711340206,
#   'negative': 0.010309278350515464},
#  'scotland': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'rb': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'barclay': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'barc': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'bc': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '17': {'positive': 0.24, 'neutral': 0.64, 'negative': 0.12},
#  'corp': {'positive': 0.3125, 'neutral': 0.65625, 'negative': 0.03125},
#  'thursday': {'positive': 0.5,
#   'neutral': 0.4444444444444444,
#   'negative': 0.05555555555555555},
#  'cell': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'phone': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'thirdquart': {'positive': 0.75, 'neutral': 0.0, 'negative': 0.25},
#  'global': {'positive': 0.30303030303030304,
#   'neutral': 0.696969696969697,
#   'negative': 0.0},
#  'financi': {'positive': 0.2702702702702703,
#   'neutral': 0.7207207207207207,
#   'negative': 0.009009009009009009},
#  'publish': {'positive': 0.05263157894736842,
#   'neutral': 0.9473684210526315,
#   'negative': 0.0},
#  'friday': {'positive': 0.4074074074074074,
#   'neutral': 0.5925925925925926,
#   'negative': 0.0},
#  'seb': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'soar': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'sek6': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '745': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'bn': {'positive': 0.3684210526315789,
#   'neutral': 0.631578947368421,
#   'negative': 0.0},
#  'sek1': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '50': {'positive': 0.4166666666666667,
#   'neutral': 0.5416666666666666,
#   'negative': 0.041666666666666664},
#  'meanwhil': {'positive': 0.8, 'neutral': 0.2, 'negative': 0.0},
#  'request': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'alma': {'positive': 0.06896551724137931,
#   'neutral': 0.9310344827586207,
#   'negative': 0.0},
#  'newspap': {'positive': 0.07692307692307693,
#   'neutral': 0.9230769230769231,
#   'negative': 0.0},
#  'research': {'positive': 0.07407407407407407,
#   'neutral': 0.9259259259259259,
#   'negative': 0.0},
#  'manag': {'positive': 0.2868217054263566,
#   'neutral': 0.689922480620155,
#   'negative': 0.023255813953488372},
#  'jari': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'kaivooja': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'futur': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'centr': {'positive': 0.36363636363636365,
#   'neutral': 0.6363636363636364,
#   'negative': 0.0},
#  'turku': {'positive': 0.1111111111111111,
#   'neutral': 0.6666666666666666,
#   'negative': 0.2222222222222222},
#  'school': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'econom': {'positive': 0.07692307692307693,
#   'neutral': 0.9230769230769231,
#   'negative': 0.0},
#  'drawn': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'scenario': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'nation': {'positive': 0.29411764705882354,
#   'neutral': 0.5882352941176471,
#   'negative': 0.11764705882352941},
#  'model': {'positive': 0.28, 'neutral': 0.72, 'negative': 0.0},
#  'univers': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'denver': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'sweden': {'positive': 0.325, 'neutral': 0.675, 'negative': 0.0},
# ...
#  'food': {'positive': 0.35294117647058826,
#   'neutral': 0.6470588235294118,
#   'negative': 0.0},
#  'l�nnen': {'positive': 0.1111111111111111,
#   'neutral': 0.8888888888888888,
#   'negative': 0.0},
#  'tehtaat': {'positive': 0.1111111111111111,
#   'neutral': 0.8888888888888888,
#   'negative': 0.0},
#  '3491': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '3096': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'individu': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'promot': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'higherthanexpect': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'mani': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'genesi': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'respect': {'positive': 0.7777777777777778,
#   'neutral': 0.18518518518518517,
#   'negative': 0.037037037037037035},
#  'eur8': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'circul': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '70': {'positive': 0.26666666666666666,
#   'neutral': 0.7333333333333333,
#   'negative': 0.0},
#  '308': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '1015': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'annual': {'positive': 0.3, 'neutral': 0.7, 'negative': 0.0},
#  'swedish': {'positive': 0.4117647058823529,
#   'neutral': 0.5588235294117647,
#   'negative': 0.029411764705882353},
#  'experienc': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'howev': {'positive': 0.46153846153846156,
#   'neutral': 0.4358974358974359,
#   'negative': 0.10256410256410256},
#  'favour': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'trend': {'positive': 0.5, 'neutral': 0.4, 'negative': 0.1},
#  'cash': {'positive': 0.37142857142857144,
#   'neutral': 0.5142857142857142,
#   'negative': 0.11428571428571428},
#  'flow': {'positive': 0.6, 'neutral': 0.3, 'negative': 0.1},
#  'activ': {'positive': 0.1956521739130435,
#   'neutral': 0.8043478260869565,
#   'negative': 0.0},
#  'eur121m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur97m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'lithuania': {'positive': 0.5454545454545454,
#   'neutral': 0.45454545454545453,
#   'negative': 0.0},
#  '190000': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '70000': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'fourth': {'positive': 0.5, 'neutral': 0.4, 'negative': 0.1},
#  '10507': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '10270': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '598': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '12444': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'kalmar': {'positive': 0.375, 'neutral': 0.625, 'negative': 0.0},
#  'espana': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  '113': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  '148': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'x20ac': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '402': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '585u': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '401': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur655m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur438m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '255': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur59': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'charger': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'deliv': {'positive': 0.38333333333333336,
#   'neutral': 0.6166666666666667,
#   'negative': 0.0},
#  '41': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '659': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'piec': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '936': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '932': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'note': {'positive': 0.2857142857142857,
#   'neutral': 0.7142857142857143,
#   'negative': 0.0},
#  'declin': {'positive': 0.125, 'neutral': 0.5, 'negative': 0.375},
#  'though': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'mobil': {'positive': 0.34951456310679613,
#   'neutral': 0.6504854368932039,
#   'negative': 0.0},
#  'yearago': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '1451': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '83': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  '34': {'positive': 0.4, 'neutral': 0.5, 'negative': 0.1},
#  '117': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '5mn': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '28': {'positive': 0.5909090909090909,
#   'neutral': 0.4090909090909091,
#   'negative': 0.0},
#  '245': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '230': {'positive': 0.3333333333333333,
#   'neutral': 0.3333333333333333,
#   'negative': 0.3333333333333333},
#  'ramir': {'positive': 0.6428571428571429,
#   'neutral': 0.35714285714285715,
#   'negative': 0.0},
#  'quarterend': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '1287': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '163': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '33percent': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '1246': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'thesecond': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '580': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '743': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '569': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'ruukki': {'positive': 0.5,
#   'neutral': 0.4117647058823529,
#   'negative': 0.08823529411764706},
#  'aker': {'positive': 0.6666666666666666,
#   'neutral': 0.16666666666666666,
#   'negative': 0.16666666666666666},
#  'norway': {'positive': 0.21428571428571427,
#   'neutral': 0.7857142857142857,
#   'negative': 0.0},
#  'suction': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'anchor': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'kalajoki': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'show': {'positive': 0.2222222222222222,
#   'neutral': 0.6666666666666666,
#   'negative': 0.1111111111111111},
#  'eur647m': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ceo': {'positive': 0.3968253968253968,
#   'neutral': 0.6031746031746031,
#   'negative': 0.0},
#  'sakari': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'tamminen': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'magazin': {'positive': 0.35294117647058826,
#   'neutral': 0.6470588235294118,
#   'negative': 0.0},
#  'gdp': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'overal': {'positive': 0.7, 'neutral': 0.3, 'negative': 0.0},
#  'weekli': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'basi': {'positive': 0.45454545454545453,
#   'neutral': 0.5454545454545454,
#   'negative': 0.0},
#  '40000': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '50000': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '1586': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '414': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'cent': {'positive': 0.2727272727272727,
#   'neutral': 0.6363636363636364,
#   'negative': 0.09090909090909091},
#  '2803': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'end': {'positive': 0.3108108108108108,
#   'neutral': 0.6216216216216216,
#   'negative': 0.06756756756756757},
#  '2691': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'ago': {'positive': 0.9411764705882353,
#   'neutral': 0.0,
#   'negative': 0.058823529411764705},
#  'best': {'positive': 0.5714285714285714,
#   'neutral': 0.42857142857142855,
#   'negative': 0.0},
#  'major': {'positive': 0.25,
#   'neutral': 0.6818181818181818,
#   'negative': 0.06818181818181818},
#  'breweri': {'positive': 0.8333333333333334,
#   'neutral': 0.16666666666666666,
#   'negative': 0.0},
#  'domest': {'positive': 0.46153846153846156,
#   'neutral': 0.5384615384615384,
#   'negative': 0.0},
#  '25688': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'litr': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  '24592': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'transact': {'positive': 0.19607843137254902,
#   'neutral': 0.803921568627451,
#   'negative': 0.0},
#  'tecnomen': {'positive': 0.4166666666666667,
#   'neutral': 0.5833333333333334,
#   'negative': 0.0},
#  'workfors': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'add': {'positive': 0.7, 'neutral': 0.3, 'negative': 0.0},
#  '269': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '1058': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '834': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'rental': {'positive': 0.2727272727272727,
#   'neutral': 0.7272727272727273,
#   'negative': 0.0},
#  'latvian': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'prioriti': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'balanc': {'positive': 0.36363636363636365,
#   'neutral': 0.6363636363636364,
#   'negative': 0.0},
#  'sheet': {'positive': 0.2222222222222222,
#   'neutral': 0.7777777777777778,
#   'negative': 0.0},
#  'hannu': {'positive': 0.14285714285714285,
#   'neutral': 0.8571428571428571,
#   'negative': 0.0},
#  'krook': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'yit': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'build': {'positive': 0.17391304347826086,
#   'neutral': 0.8152173913043478,
#   'negative': 0.010869565217391304},
#  'geograph': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '21': {'positive': 0.38461538461538464,
#   'neutral': 0.6153846153846154,
#   'negative': 0.0},
#  'octob': {'positive': 0.2978723404255319,
#   'neutral': 0.6595744680851063,
#   'negative': 0.0425531914893617},
#  'fish': {'positive': 0.23529411764705882,
#   'neutral': 0.7647058823529411,
#   'negative': 0.0},
#  'tackl': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'rapala': {'positive': 0.4666666666666667,
#   'neutral': 0.5333333333333333,
#   'negative': 0.0},
#  'vmc': {'positive': 0.2857142857142857,
#   'neutral': 0.7142857142857143,
#   'negative': 0.0},
#  'rap1v': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'eur18': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'nine': {'positive': 0.75,
#   'neutral': 0.19444444444444445,
#   'negative': 0.05555555555555555},
#  'eur15': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  'bim': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'inform': {'positive': 0.1320754716981132,
#   'neutral': 0.8490566037735849,
#   'negative': 0.018867924528301886},
#  'softwar': {'positive': 0.3448275862068966,
#   'neutral': 0.6379310344827587,
#   'negative': 0.017241379310344827},
#  'tekla': {'positive': 0.21052631578947367,
#   'neutral': 0.7894736842105263,
#   'negative': 0.0},
#  'modelbas': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'adopt': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'project': {'positive': 0.32323232323232326,
#   'neutral': 0.6666666666666666,
#   'negative': 0.010101010101010102},
#  'abu': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'dhabi': {'positive': 0.0, 'neutral': 1.0, 'negative': 0.0},
#  'metso': {'positive': 0.48148148148148145,
#   'neutral': 0.4444444444444444,
#   'negative': 0.07407407407407407},
#  'miner': {'positive': 0.625, 'neutral': 0.375, 'negative': 0.0},
#  'gone': {'positive': 0.6666666666666666,
#   'neutral': 0.0,
#   'negative': 0.3333333333333333},
#  '19': {'positive': 0.32142857142857145,
#   'neutral': 0.6428571428571429,
#   'negative': 0.03571428571428571},
#  'aldata': {'positive': 0.15384615384615385,
#   'neutral': 0.8461538461538461,
#   'negative': 0.0},
#  'gold': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'french': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  '213': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '61': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '470': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '66': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'forest': {'positive': 0.48, 'neutral': 0.52, 'negative': 0.0},
#  'machineri': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'ponss': {'positive': 0.6666666666666666,
#   'neutral': 0.3333333333333333,
#   'negative': 0.0},
#  '513': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '375': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'kci': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'konecran': {'positive': 0.7333333333333333,
#   'neutral': 0.2,
#   'negative': 0.06666666666666667},
#  '35': {'positive': 0.42857142857142855,
#   'neutral': 0.5714285714285714,
#   'negative': 0.0},
#  'okmet': {'positive': 0.3157894736842105,
#   'neutral': 0.631578947368421,
#   'negative': 0.05263157894736842},
#  'silicon': {'positive': 0.6, 'neutral': 0.4, 'negative': 0.0},
#  'wafer': {'positive': 0.625, 'neutral': 0.375, 'negative': 0.0},
#  'semiconductor': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'sensor': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'norwegian': {'positive': 0.6363636363636364,
#   'neutral': 0.36363636363636365,
#   'negative': 0.0},
#  'solar': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'norsun': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'mono': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'crystal': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'pharmaceut': {'positive': 0.24, 'neutral': 0.68, 'negative': 0.08},
#  'orion': {'positive': 0.5, 'neutral': 0.3, 'negative': 0.2},
#  '190mn': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '180mn': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'babcock': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'distribut': {'positive': 0.24444444444444444,
#   'neutral': 0.7555555555555555,
#   'negative': 0.0},
#  'harvest': {'positive': 0.8, 'neutral': 0.2, 'negative': 0.0},
#  'head': {'positive': 0.39285714285714285,
#   'neutral': 0.6071428571428571,
#   'negative': 0.0},
#  'south': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'african': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'sappi': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'foreign': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'graphic': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'deputi': {'positive': 0.2, 'neutral': 0.8, 'negative': 0.0},
#  'md': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'pekka': {'positive': 0.75, 'neutral': 0.25, 'negative': 0.0},
#  'silvennoinen': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  'aim': {'positive': 0.5714285714285714,
#   'neutral': 0.40816326530612246,
#   'negative': 0.02040816326530612},
#  'next': {'positive': 0.3870967741935484,
#   'neutral': 0.6129032258064516,
#   'negative': 0.0},
#  'hkscan': {'positive': 0.25, 'neutral': 0.75, 'negative': 0.0},
#  'j�rvisuomen': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  'portti': {'positive': 0.3333333333333333,
#   'neutral': 0.6666666666666666,
#   'negative': 0.0},
#  '80mn': {'positive': 1.0, 'neutral': 0.0, 'negative': 0.0},
#  '100mn': {'positive': 0.5, 'neutral': 0.5, 'negative': 0.0},
#  'advertis': {'positive': 0.3333333333333333,
#   'neutral': 0.5555555555555556,
#   'negative': 0.1111111111111111},
#  '04': {'positive': 0.7777777777777778,
#   'neutral': 0.1111111111111111,
#   'negative': 0.1111111111111111},
#  'takeov': {'positive': 0.3333333333333333,
#   'neutral': 0.5,
#   'negative': 0.16666666666666666},
#  'signific': {'positive': 0.6216216216216216,
#   'neutral': 0.3783783783783784,
#   'negative': 0.0},
#  'previous': {'positive': 0.2916666666666667,
#   'neutral': 0.6666666666666666,
#   'negative': 0.041666666666666664},
#  'lemmink�inen': {'positive': 0.4, 'neutral': 0.6, 'negative': 0.0},
#  ...}

# %% [markdown]
# *   If you need to implement some additional methods, feel free to do it.

# %% [markdown]
# 31634  - symbol values [".", ",", "(", ")", ":", "&","-", "\"","[","]", "?"]

# %% [markdown]
# 30458 - replacing all punctuation

# %% [markdown]
# 23106 - using stemmer

# %% [markdown]
# ### Implementation
# Implement each method of the BayesianClassifier
# created according to its description.

# %%
class BayesianClassifier:
    """
    Implementation of Naive Bayes classification algorithm.
    """
    def __init__(self):
        self.model: pd.DataFrame = None
        self.lbl_properties: pd.DataFrame = None

    def fit(self, X, y):
        """
        Fit Naive Bayes parameters according to train data X and y.
        :param X: pd.DataFrame|list - train input/messages
        :param y: pd.DataFrame|list - train output/labels
        :return: None
        """
        record = {'word': ['difficult', 'exercise', 'play', 'football'],
                   'positive': [0.09, 0.3, 0.12, 0.9],
                   'neutral': [0.2, 0.5, 0.01, 0.3],
                   'negative': [0.2, 0.5, 0.01, 0.15],
                   'total': [0.25, 0.25, 0.25, 0.25]}
        
        lbl_properties = {'label': ['positive', 'neutral', 'negative'],
                          'prob': [0.2, 0.3, 0.7]}
        
        self.model = pd.DataFrame(record, columns = ['word', 'positive', 'neutral', 'negative', 'total'])
        self.lbl_properties = pd.DataFrame(lbl_properties, columns = ['label', 'words_count', 'prob'])

    def predict_prob(self, message, label):
        """
        Calculate the probability that a given label can be assigned to a given message.
        :param message: str - input message
        :param label: str - label
        :return: float - probability P(label|message)
        """
        model = self.model
        lbl_props = self.lbl_properties
        
        multiplication = 1
        for word, count in message.items():
            word_info = model.loc[model['word'] == word]
            if len(word_info) != 0:
                word_info = word_info.iloc[0]
                word_cond = word_info[label]
                word_tot = word_info['total']
            else:
                # probability of word out of base
                # doesn't affect in comparison
                word_cond = 1
                word_tot = 1
#                 word_cond = (0 + 1) / (lbl_props[lbl_props['label'] == label].iloc[0]['words_count'] + lbl_props[lbl_props['label'] == 'total'].iloc[0]['words_count'])
#                 word_tot = 1 / lbl_props[lbl_props['label'] == 'total'].iloc[0]['words_count']
            multiplication *= (word_cond / word_tot) ** count
        
        prob = lbl_props[lbl_props['label'] == label].iloc[0]['prob'] * multiplication
        
        return prob
        

    def predict(self, message):
        """
        Predict label for a given message.
        :param message: str - message
        :return: str - label that is most likely to be truly assigned to a given message
        """
        lbl_props = self.lbl_properties
        lbls = lbl_props[lbl_props['label'] != 'total']['label']
        
        probs = {}
        for lbl in lbls:
            probs[lbl] = self.predict_prob(message, lbl)
        probs = list(probs.items())
        probs.sort(key=lambda x: x[1], reverse=True)
        
        return probs[0][0]

    def score(self, X, y):
        """
        Return the mean accuracy on the given test data and labels - the efficiency of a trained model.
        :param X: pd.DataFrame|list - test data - messages
        :param y: pd.DataFrame|list - test labels
        :return:
        """
        cor_mes = 0
        all_mes = len(X.index)
        for idx, message in X.items():
            pred = self.predict(message)
            real = y.at[idx]
            if pred == real:
                cor_mes += 1

        return cor_mes / all_mes

# test
    
classifier = BayesianClassifier()
classifier.fit(None, None)
print(classifier.predict(Counter({'difficult': 1, 'football': 1, 'chicccken': 1, 'Alps': 3})))
print(classifier.predict(Counter({'play': 1, 'chicccken': 1, 'Alps': 3})))

# %% [markdown]
# ### Testing
# *  Finally, after you are done with your classifier, test it.

# %%
train_X, train_y = None, None
# test_X, test_y = process_data("your test data file")

classifier = BayesianClassifier()
classifier.fit(train_X, train_y)
# classifier.predict_prob(Counter({'play': 1, 'football': 1, 'chicccken': 1}), 'positive')
classifier.predict(Counter({'difficult': 1, 'football': 1, 'chicccken': 1, 'Alps': 3}))

# print("model score: ", classifier.score(test_X, test_y))

# %% [markdown]
# ## Conclusions
#
# Summarize your work by explaining in a few sentences the points listed below

# %% [markdown]
# * ### Describe the method implemented in general:

# %% [markdown]
# * ### List pros and cons of the method:

# %% [markdown]
# * ### Add a few sencences about your implementation of the classifier:

# %% [markdown]
# * ### Describe your results:
